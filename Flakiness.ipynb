# %% [markdown]
# ### Towards a Bayesian Network Model for Predicting Flaky Automated Tests

# %%
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-0.1.18-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 14.6 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from pgmpy) (1.10.0+cu111)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pgmpy) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pgmpy) (4.63.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pgmpy) (2.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pgmpy) (1.21.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pgmpy) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from pgmpy) (3.0.7)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from pgmpy) (0.10.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pgmpy) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pgmpy) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pgmpy) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->pgmpy) (3.10.0.2)
# Installing collected packages: pgmpy
# Successfully installed pgmpy-0.1.18

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

from pgmpy.sampling import BayesianModelSampling
from pgmpy.factors.discrete import State
# from pgmpy.sampling import GibbsSampling
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
Flakiness_model = BayesianNetwork(
    [
        ("DI", "HTC"),
        ("LTFS", "HTC"),
        ("HAC", "HTC"),
        ("LTMS", "HTC"),
        ("HTC", "TF"), 
        ("ND", "TF"),
        ("EW", "ND"),
        ("CL", "ND"),
        ("IS", "TF"),
        ("IC", "TF"),
                
    ]
)

nodes = list(Flakiness_model.nodes())
edges = list(Flakiness_model.edges())

print('The nodes of the net are: {}'.format(nodes))
print('The edges of the net are: {}'.format(edges))
# Out:
# The nodes of the net are: ['DI', 'HTC', 'LTFS', 'HAC', 'LTMS', 'TF', 'ND', 'EW', 'CL', 'IS', 'IC']
# The edges of the net are: [('DI', 'HTC'), ('HTC', 'TF'), ('LTFS', 'HTC'), ('HAC', 'HTC'), ('LTMS', 'HTC'), ('ND', 'TF'), ('EW', 'ND'), ('CL', 'ND'), ('IS', 'TF'), ('IC', 'TF')]

# %%
DAG = nx.DiGraph()
DAG.add_edges_from(edges)

fig = plt.figure(figsize = (16,12))
pos = nx.spring_layout(DAG) 

nx.draw_networkx_nodes(DAG, pos = pos, node_color = 'yellow')
nx.draw_networkx_labels(DAG, pos = pos)
nx.draw_networkx_edges(DAG, pos = pos, edge_color = 'purple', width = 1.5, arrows = True)

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cpd_di = TabularCPD(variable="DI", variable_card=2, values=[[0.06], [0.94]])
cpd_ltfs = TabularCPD(variable="LTFS", variable_card=2, values=[[0.8], [0.2]])
cpd_hac = TabularCPD(variable="HAC", variable_card=2, values=[[0.3], [0.7]])
cpd_ltms = TabularCPD(variable="LTMS", variable_card=2, values=[[0.8], [0.2]])
cpd_ew = TabularCPD(variable="EW", variable_card=2, values=[[0.95], [0.05]])
cpd_cl = TabularCPD(variable="CL", variable_card=2, values=[[0.85], [0.15]])
cpd_is = TabularCPD(variable="IS", variable_card=2, values=[[0.98], [0.02]])
cpd_ic = TabularCPD(variable="IC", variable_card=2, values=[[0.1], [0.9]])
cpd_nd = TabularCPD(
    variable="ND",
    variable_card=2,
    values=[[0.99, 0.35, 0.49, 0.15], [0.01, 0.65, 0.51, 0.85]],
    evidence=["EW", "CL"],
    evidence_card=[2, 2],
)
cpd_htc = TabularCPD(
    variable="HTC",
    variable_card=2,
    values=[[0.95, 0.85, 0.85, 0.25, 0.9, 0.24, 0.25, 0.1, 0.88, 0.26, 0.15, 0.11, 0.25, 0.1, 0.1, 0.01 ],
            [0.05, 0.15, 0.15, 0.75, 0.1, 0.76, 0.75, 0.9, 0.12, 0.74, 0.85, 0.89, 0.75, 0.9, 0.9, 0.99]],
    evidence=["DI", "LTFS", "HAC", "LTMS"],
    evidence_card=[2,2,2,2],
)
cpd_tf = TabularCPD(
    variable="TF",
    variable_card=2,
    values=[[0.9, 0.8, 0.75, 0.2, 0.76, 0.17, 0.17, 0.11, 0.77, 0.15, 0.16, 0.11, 0.15, 0.1, 0.1, 0.05], 
            [0.1, 0.2, 0.25, 0.8, 0.24, 0.83, 0.83, 0.89, 0.23, 0.85, 0.84, 0.89, 0.85, 0.9, 0.9, 0.95]],
    evidence=["HTC", "ND", "IC", "IS"],
    evidence_card=[2,2,2,2],
)

print (cpd_di)

print (cpd_htc)
print (cpd_tf)
# Out:
# +-------+------+
# | DI(0) | 0.06 |
# +-------+------+
# | DI(1) | 0.94 |
# +-------+------+
# +--------+---------+---------+-----+---------+---------+---------+
# | DI     | DI(0)   | DI(0)   | ... | DI(1)   | DI(1)   | DI(1)   |
# +--------+---------+---------+-----+---------+---------+---------+
# | LTFS   | LTFS(0) | LTFS(0) | ... | LTFS(1) | LTFS(1) | LTFS(1) |
# +--------+---------+---------+-----+---------+---------+---------+
# | HAC    | HAC(0)  | HAC(0)  | ... | HAC(0)  | HAC(1)  | HAC(1)  |
# +--------+---------+---------+-----+---------+---------+---------+
# | LTMS   | LTMS(0) | LTMS(1) | ... | LTMS(1) | LTMS(0) | LTMS(1) |
# +--------+---------+---------+-----+---------+---------+---------+
# | HTC(0) | 0.95    | 0.85    | ... | 0.1     | 0.1     | 0.01    |
# +--------+---------+---------+-----+---------+---------+---------+
# | HTC(1) | 0.05    | 0.15    | ... | 0.9     | 0.9     | 0.99    |
# +--------+---------+---------+-----+---------+---------+---------+
# +-------+--------+--------+--------+-----+--------+--------+--------+
# | HTC   | HTC(0) | HTC(0) | HTC(0) | ... | HTC(1) | HTC(1) | HTC(1) |
# +-------+--------+--------+--------+-----+--------+--------+--------+
# | ND    | ND(0)  | ND(0)  | ND(0)  | ... | ND(1)  | ND(1)  | ND(1)  |
# +-------+--------+--------+--------+-----+--------+--------+--------+
# | IC    | IC(0)  | IC(0)  | IC(1)  | ... | IC(0)  | IC(1)  | IC(1)  |
# +-------+--------+--------+--------+-----+--------+--------+--------+
# | IS    | IS(0)  | IS(1)  | IS(0)  | ... | IS(1)  | IS(0)  | IS(1)  |
# +-------+--------+--------+--------+-----+--------+--------+--------+
# | TF(0) | 0.9    | 0.8    | 0.75   | ... | 0.1    | 0.1    | 0.05   |
# +-------+--------+--------+--------+-----+--------+--------+--------+
# | TF(1) | 0.1    | 0.2    | 0.25   | ... | 0.9    | 0.9    | 0.95   |
# +-------+--------+--------+--------+-----+--------+--------+--------+

# %%
cpds = {}

cpds['DI'] = cpd_di
cpds['LTFS']=cpd_ltfs
cpds['HAC']=cpd_hac
cpds['LTMS']=cpd_ltms
cpds["EW"]=cpd_ew
cpds['CL']=cpd_cl
cpds["IS"]=cpd_is
cpds["IC"]=cpd_ic
cpds["ND"]=cpd_nd
cpds["HTC"]=cpd_htc
cpds["TF"]=cpd_tf

# %%
# Associating the parameters with the model structure.
Flakiness_model.add_cpds(cpd_di, cpd_ltfs, cpd_hac, cpd_ltms, cpd_ew, cpd_cl, cpd_is,cpd_ic, cpd_nd, cpd_htc,cpd_tf )

# Checking if the cpds are valid for the model.
Flakiness_model.check_model()
# Out:
# True

# %%
# Get all model implied independence conditions

Flakiness_model.get_independencies()
# Out:
# (IS ⟂ LTMS, CL, HTC, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ CL, HTC, LTFS, DI, EW, IC, ND, HAC | LTMS)
# (IS ⟂ LTMS, HTC, LTFS, DI, EW, IC, ND, HAC | CL)
# (IS ⟂ LTMS, CL, LTFS, DI, EW, IC, ND, HAC | HTC)
# (IS ⟂ LTMS, CL, HTC, DI, EW, IC, ND, HAC | LTFS)
# (IS ⟂ LTMS, CL, HTC, LTFS, EW, IC, ND, HAC | DI)
# (IS ⟂ LTMS, CL, HTC, LTFS, DI, IC, ND, HAC | EW)
# (IS ⟂ LTMS, CL, HTC, LTFS, DI, EW, ND, HAC | IC)
# (IS ⟂ LTMS, CL, HTC, LTFS, DI, EW, IC, HAC | ND)
# (IS ⟂ LTMS, CL, HTC, LTFS, DI, EW, IC, ND | HAC)
# (IS ⟂ LTFS, DI, EW, IC, HTC, HAC, ND | LTMS, CL)
# (IS ⟂ LTFS, DI, EW, IC, CL, ND, HAC | LTMS, HTC)
# (IS ⟂ DI, EW, IC, CL, HTC, HAC, ND | LTFS, LTMS)
# (IS ⟂ LTFS, EW, IC, CL, HTC, HAC, ND | LTMS, DI)
# (IS ⟂ LTFS, DI, IC, CL, HTC, HAC, ND | LTMS, EW)
# (IS ⟂ LTFS, DI, EW, CL, HTC, HAC, ND | LTMS, IC)
# (IS ⟂ LTFS, DI, EW, IC, CL, HTC, HAC | LTMS, ND)
# (IS ⟂ LTFS, DI, EW, IC, CL, HTC, ND | LTMS, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, ND, IC, HAC | CL, HTC)
# (IS ⟂ HAC, DI, EW, LTMS, HTC, IC, ND | LTFS, CL)
# (IS ⟂ LTFS, HAC, EW, LTMS, HTC, IC, ND | CL, DI)
# (IS ⟂ LTFS, HAC, DI, LTMS, HTC, IC, ND | CL, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC, HAC, ND | IC, CL)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC, IC, HAC | CL, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC, IC, ND | CL, HAC)
# (IS ⟂ DI, EW, LTMS, CL, ND, IC, HAC | LTFS, HTC)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, HTC)
# (IS ⟂ LTFS, EW, LTMS, CL, ND, IC, HAC | HTC, DI)
# (IS ⟂ LTFS, DI, LTMS, CL, ND, IC, HAC | HTC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, ND, HAC | IC, HTC)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, IC, HAC | HTC, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, ND, IC | HTC, HAC)
# (IS ⟂ HAC, EW, LTMS, CL, HTC, IC, ND | LTFS, DI)
# (IS ⟂ HAC, DI, LTMS, CL, HTC, IC, ND | LTFS, EW)
# (IS ⟂ DI, EW, LTMS, CL, HTC, HAC, ND | LTFS, IC)
# (IS ⟂ DI, EW, LTMS, CL, HTC, IC, HAC | LTFS, ND)
# (IS ⟂ DI, EW, LTMS, CL, HTC, IC, ND | LTFS, HAC)
# (IS ⟂ CL, EW | TF, ND)
# (IS ⟂ LTFS, HAC, LTMS, CL, HTC, IC, ND | DI, EW)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC, HAC, ND | IC, DI)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC, IC, HAC | ND, DI)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC, IC, ND | DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC, HAC, ND | IC, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC, IC, HAC | ND, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC, IC, ND | HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HTC, HAC | IC, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HTC, ND | IC, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HTC, IC | ND, HAC)
# (IS ⟂ LTFS, DI, EW, IC, ND, HAC | LTMS, CL, HTC)
# (IS ⟂ DI, EW, IC, HTC, HAC, ND | LTFS, LTMS, CL)
# (IS ⟂ LTFS, EW, IC, HTC, HAC, ND | LTMS, CL, DI)
# (IS ⟂ LTFS, DI, IC, HTC, HAC, ND | LTMS, CL, EW)
# (IS ⟂ LTFS, DI, EW, HTC, HAC, ND | LTMS, CL, IC)
# (IS ⟂ LTFS, DI, EW, IC, HTC, HAC | LTMS, CL, ND)
# (IS ⟂ LTFS, DI, EW, IC, HTC, ND | LTMS, CL, HAC)
# (IS ⟂ DI, EW, IC, CL, ND, HAC | LTFS, LTMS, HTC)
# (IS ⟂ LTFS, DI, HAC | TF, LTMS, HTC)
# (IS ⟂ LTFS, EW, IC, CL, ND, HAC | LTMS, HTC, DI)
# (IS ⟂ LTFS, DI, IC, CL, ND, HAC | LTMS, HTC, EW)
# (IS ⟂ LTFS, DI, EW, CL, ND, HAC | LTMS, HTC, IC)
# (IS ⟂ LTFS, DI, EW, IC, CL, HAC | LTMS, HTC, ND)
# (IS ⟂ LTFS, DI, EW, IC, CL, ND | LTMS, HTC, HAC)
# (IS ⟂ EW, IC, CL, HTC, HAC, ND | LTFS, LTMS, DI)
# (IS ⟂ DI, IC, CL, HTC, HAC, ND | LTFS, LTMS, EW)
# (IS ⟂ DI, EW, CL, HTC, HAC, ND | LTFS, LTMS, IC)
# (IS ⟂ DI, EW, IC, CL, HTC, HAC | LTFS, LTMS, ND)
# (IS ⟂ DI, EW, IC, CL, HTC, ND | LTFS, LTMS, HAC)
# (IS ⟂ CL, EW | TF, LTMS, ND)
# (IS ⟂ LTFS, IC, CL, HTC, HAC, ND | LTMS, DI, EW)
# (IS ⟂ LTFS, EW, CL, HTC, HAC, ND | LTMS, DI, IC)
# (IS ⟂ LTFS, EW, IC, CL, HTC, HAC | LTMS, ND, DI)
# (IS ⟂ LTFS, EW, IC, CL, HTC, ND | LTMS, DI, HAC)
# (IS ⟂ LTFS, DI, CL, HTC, HAC, ND | LTMS, IC, EW)
# (IS ⟂ LTFS, DI, IC, CL, HTC, HAC | LTMS, ND, EW)
# (IS ⟂ LTFS, DI, IC, CL, HTC, ND | LTMS, HAC, EW)
# (IS ⟂ LTFS, DI, EW, CL, HTC, HAC | LTMS, ND, IC)
# (IS ⟂ LTFS, DI, EW, CL, HTC, ND | LTMS, IC, HAC)
# (IS ⟂ LTFS, DI, EW, IC, CL, HTC | LTMS, ND, HAC)
# (IS ⟂ DI, EW, LTMS, ND, IC, HAC | LTFS, CL, HTC)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, CL, HTC)
# (IS ⟂ LTFS, EW, LTMS, ND, IC, HAC | CL, HTC, DI)
# (IS ⟂ LTFS, DI, LTMS, ND, IC, HAC | CL, HTC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, ND, HAC | IC, CL, HTC)
# (IS ⟂ LTFS, DI, EW, LTMS, IC, HAC | CL, HTC, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, ND, IC | CL, HTC, HAC)
# (IS ⟂ HAC, EW, LTMS, HTC, IC, ND | LTFS, CL, DI)
# (IS ⟂ HAC, DI, LTMS, HTC, IC, ND | LTFS, CL, EW)
# (IS ⟂ DI, EW, LTMS, HTC, HAC, ND | LTFS, IC, CL)
# (IS ⟂ DI, EW, LTMS, HTC, IC, HAC | LTFS, CL, ND)
# (IS ⟂ DI, EW, LTMS, HTC, IC, ND | LTFS, CL, HAC)
# (IS ⟂ EW | TF, CL, ND)
# (IS ⟂ LTFS, HAC, LTMS, HTC, IC, ND | CL, DI, EW)
# (IS ⟂ LTFS, EW, LTMS, HTC, HAC, ND | IC, CL, DI)
# (IS ⟂ LTFS, EW, LTMS, HTC, IC, HAC | CL, ND, DI)
# (IS ⟂ LTFS, EW, LTMS, HTC, IC, ND | CL, DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, HTC, HAC, ND | IC, CL, EW)
# (IS ⟂ LTFS, DI, LTMS, HTC, IC, HAC | CL, ND, EW)
# (IS ⟂ LTFS, DI, LTMS, HTC, IC, ND | CL, HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC, HAC | IC, CL, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC, ND | IC, CL, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC, IC | CL, ND, HAC)
# (IS ⟂ LTMS, DI, HAC | LTFS, TF, HTC)
# (IS ⟂ EW, LTMS, CL, ND, IC, HAC | LTFS, HTC, DI)
# (IS ⟂ DI, LTMS, CL, ND, IC, HAC | LTFS, HTC, EW)
# (IS ⟂ DI, EW, LTMS, CL, ND, HAC | LTFS, IC, HTC)
# (IS ⟂ DI, EW, LTMS, CL, IC, HAC | LTFS, HTC, ND)
# (IS ⟂ DI, EW, LTMS, CL, ND, IC | LTFS, HTC, HAC)
# (IS ⟂ LTFS, LTMS, HAC | TF, HTC, DI)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, HTC, EW)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, IC, HTC)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HAC | TF, HTC, ND)
# (IS ⟂ LTFS, LTMS, DI | TF, HTC, HAC)
# (IS ⟂ LTFS, LTMS, CL, ND, IC, HAC | HTC, DI, EW)
# (IS ⟂ LTFS, EW, LTMS, CL, ND, HAC | IC, HTC, DI)
# (IS ⟂ LTFS, EW, LTMS, CL, IC, HAC | HTC, DI, ND)
# (IS ⟂ LTFS, EW, LTMS, CL, ND, IC | HTC, DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, CL, ND, HAC | IC, HTC, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, IC, HAC | HTC, ND, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, ND, IC | HTC, HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HAC | IC, HTC, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, ND | IC, HTC, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, IC | HTC, HAC, ND)
# (IS ⟂ CL, EW | LTFS, TF, ND)
# (IS ⟂ HAC, LTMS, CL, HTC, IC, ND | LTFS, DI, EW)
# (IS ⟂ EW, LTMS, CL, HTC, HAC, ND | LTFS, IC, DI)
# (IS ⟂ EW, LTMS, CL, HTC, IC, HAC | LTFS, ND, DI)
# (IS ⟂ EW, LTMS, CL, HTC, IC, ND | LTFS, DI, HAC)
# (IS ⟂ DI, LTMS, CL, HTC, HAC, ND | LTFS, IC, EW)
# (IS ⟂ DI, LTMS, CL, HTC, IC, HAC | LTFS, ND, EW)
# (IS ⟂ DI, LTMS, CL, HTC, IC, ND | LTFS, HAC, EW)
# (IS ⟂ DI, EW, LTMS, CL, HTC, HAC | LTFS, IC, ND)
# (IS ⟂ DI, EW, LTMS, CL, HTC, ND | LTFS, IC, HAC)
# (IS ⟂ DI, EW, LTMS, CL, HTC, IC | LTFS, ND, HAC)
# (IS ⟂ CL, EW | TF, ND, DI)
# (IS ⟂ CL | TF, ND, EW)
# (IS ⟂ CL, EW | TF, IC, ND)
# (IS ⟂ CL, EW | TF, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, HTC, HAC, ND | IC, DI, EW)
# (IS ⟂ LTFS, LTMS, CL, HTC, IC, HAC | ND, DI, EW)
# (IS ⟂ LTFS, LTMS, CL, HTC, IC, ND | DI, HAC, EW)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC, HAC | IC, ND, DI)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC, ND | IC, DI, HAC)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC, IC | ND, DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC, HAC | IC, ND, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC, ND | IC, HAC, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC, IC | ND, HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HTC | IC, ND, HAC)
# (IS ⟂ DI, EW, IC, ND, HAC | LTFS, LTMS, CL, HTC)
# (IS ⟂ LTFS, DI, HAC | TF, LTMS, CL, HTC)
# (IS ⟂ LTFS, EW, IC, ND, HAC | LTMS, CL, HTC, DI)
# (IS ⟂ LTFS, DI, IC, ND, HAC | LTMS, CL, HTC, EW)
# (IS ⟂ LTFS, DI, EW, ND, HAC | LTMS, CL, HTC, IC)
# (IS ⟂ LTFS, DI, EW, IC, HAC | LTMS, CL, HTC, ND)
# (IS ⟂ LTFS, DI, EW, IC, ND | LTMS, CL, HTC, HAC)
# (IS ⟂ EW, IC, HTC, HAC, ND | LTFS, LTMS, CL, DI)
# (IS ⟂ DI, IC, HTC, HAC, ND | LTFS, LTMS, CL, EW)
# (IS ⟂ DI, EW, HTC, HAC, ND | LTFS, LTMS, CL, IC)
# (IS ⟂ DI, EW, IC, HTC, HAC | LTFS, LTMS, CL, ND)
# (IS ⟂ DI, EW, IC, HTC, ND | LTFS, LTMS, CL, HAC)
# (IS ⟂ EW | TF, LTMS, CL, ND)
# (IS ⟂ LTFS, IC, HTC, HAC, ND | LTMS, CL, DI, EW)
# (IS ⟂ LTFS, EW, HTC, HAC, ND | LTMS, CL, DI, IC)
# (IS ⟂ LTFS, EW, IC, HTC, HAC | LTMS, CL, ND, DI)
# (IS ⟂ LTFS, EW, IC, HTC, ND | LTMS, CL, DI, HAC)
# (IS ⟂ LTFS, DI, HTC, HAC, ND | LTMS, CL, IC, EW)
# (IS ⟂ LTFS, DI, IC, HTC, HAC | LTMS, CL, ND, EW)
# (IS ⟂ LTFS, DI, IC, HTC, ND | LTMS, CL, HAC, EW)
# (IS ⟂ LTFS, DI, EW, HTC, HAC | LTMS, CL, ND, IC)
# (IS ⟂ LTFS, DI, EW, HTC, ND | LTMS, CL, IC, HAC)
# (IS ⟂ LTFS, DI, EW, IC, HTC | LTMS, CL, ND, HAC)
# (IS ⟂ DI, HAC | LTFS, LTMS, TF, HTC)
# (IS ⟂ EW, IC, CL, ND, HAC | LTFS, LTMS, HTC, DI)
# (IS ⟂ DI, IC, CL, ND, HAC | LTFS, LTMS, HTC, EW)
# (IS ⟂ DI, EW, CL, ND, HAC | LTFS, LTMS, HTC, IC)
# (IS ⟂ DI, EW, IC, CL, HAC | LTFS, LTMS, HTC, ND)
# (IS ⟂ DI, EW, IC, CL, ND | LTFS, LTMS, HTC, HAC)
# (IS ⟂ LTFS, HAC | TF, LTMS, HTC, DI)
# (IS ⟂ LTFS, DI, HAC | TF, LTMS, HTC, EW)
# (IS ⟂ LTFS, DI, HAC | TF, LTMS, HTC, IC)
# (IS ⟂ LTFS, DI, EW, CL, HAC | TF, LTMS, HTC, ND)
# (IS ⟂ LTFS, DI | TF, LTMS, HTC, HAC)
# (IS ⟂ LTFS, IC, CL, ND, HAC | LTMS, HTC, DI, EW)
# (IS ⟂ LTFS, EW, CL, ND, HAC | LTMS, HTC, DI, IC)
# (IS ⟂ LTFS, EW, IC, CL, HAC | LTMS, HTC, DI, ND)
# (IS ⟂ LTFS, EW, IC, CL, ND | LTMS, HTC, DI, HAC)
# (IS ⟂ LTFS, DI, CL, ND, HAC | LTMS, HTC, IC, EW)
# (IS ⟂ LTFS, DI, IC, CL, HAC | LTMS, HTC, ND, EW)
# (IS ⟂ LTFS, DI, IC, CL, ND | LTMS, HTC, HAC, EW)
# (IS ⟂ LTFS, DI, EW, CL, HAC | LTMS, HTC, IC, ND)
# (IS ⟂ LTFS, DI, EW, CL, ND | LTMS, HTC, IC, HAC)
# (IS ⟂ LTFS, DI, EW, IC, CL | LTMS, HTC, HAC, ND)
# (IS ⟂ CL, EW | LTFS, LTMS, TF, ND)
# (IS ⟂ IC, CL, HTC, HAC, ND | LTFS, LTMS, DI, EW)
# (IS ⟂ EW, CL, HTC, HAC, ND | LTFS, LTMS, DI, IC)
# (IS ⟂ EW, IC, CL, HTC, HAC | LTFS, LTMS, ND, DI)
# (IS ⟂ EW, IC, CL, HTC, ND | LTFS, LTMS, DI, HAC)
# (IS ⟂ DI, CL, HTC, HAC, ND | LTFS, LTMS, IC, EW)
# (IS ⟂ DI, IC, CL, HTC, HAC | LTFS, LTMS, ND, EW)
# (IS ⟂ DI, IC, CL, HTC, ND | LTFS, LTMS, HAC, EW)
# (IS ⟂ DI, EW, CL, HTC, HAC | LTFS, LTMS, ND, IC)
# (IS ⟂ DI, EW, CL, HTC, ND | LTFS, LTMS, IC, HAC)
# (IS ⟂ DI, EW, IC, CL, HTC | LTFS, LTMS, ND, HAC)
# (IS ⟂ CL, EW | TF, LTMS, ND, DI)
# (IS ⟂ CL | TF, LTMS, ND, EW)
# (IS ⟂ CL, EW | TF, LTMS, ND, IC)
# (IS ⟂ CL, EW | TF, LTMS, ND, HAC)
# (IS ⟂ LTFS, CL, HTC, HAC, ND | LTMS, DI, IC, EW)
# (IS ⟂ LTFS, IC, CL, HTC, HAC | LTMS, ND, DI, EW)
# (IS ⟂ LTFS, IC, CL, HTC, ND | LTMS, DI, HAC, EW)
# (IS ⟂ LTFS, EW, CL, HTC, HAC | LTMS, ND, DI, IC)
# (IS ⟂ LTFS, EW, CL, HTC, ND | LTMS, DI, IC, HAC)
# (IS ⟂ LTFS, EW, IC, CL, HTC | LTMS, ND, DI, HAC)
# (IS ⟂ LTFS, DI, CL, HTC, HAC | LTMS, ND, IC, EW)
# (IS ⟂ LTFS, DI, CL, HTC, ND | LTMS, HAC, IC, EW)
# (IS ⟂ LTFS, DI, IC, CL, HTC | LTMS, ND, HAC, EW)
# (IS ⟂ LTFS, DI, EW, CL, HTC | LTMS, ND, IC, HAC)
# (IS ⟂ LTMS, DI, HAC | LTFS, TF, CL, HTC)
# (IS ⟂ EW, LTMS, ND, IC, HAC | LTFS, CL, HTC, DI)
# (IS ⟂ DI, LTMS, ND, IC, HAC | LTFS, CL, HTC, EW)
# (IS ⟂ DI, EW, LTMS, ND, HAC | LTFS, IC, CL, HTC)
# (IS ⟂ DI, EW, LTMS, IC, HAC | LTFS, CL, HTC, ND)
# (IS ⟂ DI, EW, LTMS, ND, IC | LTFS, CL, HTC, HAC)
# (IS ⟂ LTFS, LTMS, HAC | TF, CL, HTC, DI)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, CL, HTC, EW)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, IC, CL, HTC)
# (IS ⟂ LTFS, DI, EW, LTMS, HAC | TF, CL, HTC, ND)
# (IS ⟂ LTFS, LTMS, DI | TF, CL, HTC, HAC)
# (IS ⟂ LTFS, LTMS, ND, IC, HAC | CL, HTC, DI, EW)
# (IS ⟂ LTFS, EW, LTMS, ND, HAC | IC, CL, HTC, DI)
# (IS ⟂ LTFS, EW, LTMS, IC, HAC | CL, HTC, DI, ND)
# (IS ⟂ LTFS, EW, LTMS, ND, IC | CL, HTC, DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, ND, HAC | IC, CL, HTC, EW)
# (IS ⟂ LTFS, DI, LTMS, IC, HAC | CL, HTC, ND, EW)
# (IS ⟂ LTFS, DI, LTMS, ND, IC | CL, HTC, HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, HAC | IC, CL, HTC, ND)
# (IS ⟂ LTFS, DI, EW, LTMS, ND | IC, CL, HTC, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, IC | CL, HTC, HAC, ND)
# (IS ⟂ EW | LTFS, TF, CL, ND)
# (IS ⟂ HAC, LTMS, HTC, IC, ND | LTFS, CL, DI, EW)
# (IS ⟂ EW, LTMS, HTC, HAC, ND | LTFS, IC, CL, DI)
# (IS ⟂ EW, LTMS, HTC, IC, HAC | LTFS, CL, ND, DI)
# (IS ⟂ EW, LTMS, HTC, IC, ND | LTFS, CL, DI, HAC)
# (IS ⟂ DI, LTMS, HTC, HAC, ND | LTFS, IC, CL, EW)
# (IS ⟂ DI, LTMS, HTC, IC, HAC | LTFS, CL, ND, EW)
# (IS ⟂ DI, LTMS, HTC, IC, ND | LTFS, CL, HAC, EW)
# (IS ⟂ DI, EW, LTMS, HTC, HAC | LTFS, IC, CL, ND)
# (IS ⟂ DI, EW, LTMS, HTC, ND | LTFS, IC, CL, HAC)
# (IS ⟂ DI, EW, LTMS, HTC, IC | LTFS, CL, ND, HAC)
# (IS ⟂ EW | TF, CL, ND, DI)
# (IS ⟂ EW | TF, IC, CL, ND)
# (IS ⟂ EW | TF, CL, ND, HAC)
# (IS ⟂ LTFS, LTMS, HTC, HAC, ND | IC, CL, DI, EW)
# (IS ⟂ LTFS, LTMS, HTC, IC, HAC | CL, ND, DI, EW)
# (IS ⟂ LTFS, LTMS, HTC, IC, ND | CL, DI, HAC, EW)
# (IS ⟂ LTFS, EW, LTMS, HTC, HAC | IC, CL, ND, DI)
# (IS ⟂ LTFS, EW, LTMS, HTC, ND | IC, CL, DI, HAC)
# (IS ⟂ LTFS, EW, LTMS, HTC, IC | CL, ND, DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, HTC, HAC | IC, CL, ND, EW)
# (IS ⟂ LTFS, DI, LTMS, HTC, ND | IC, CL, HAC, EW)
# (IS ⟂ LTFS, DI, LTMS, HTC, IC | CL, ND, HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, HTC | IC, CL, ND, HAC)
# (IS ⟂ LTMS, HAC | LTFS, TF, HTC, DI)
# (IS ⟂ LTMS, DI, HAC | LTFS, TF, HTC, EW)
# (IS ⟂ LTMS, DI, HAC | LTFS, IC, TF, HTC)
# (IS ⟂ DI, EW, LTMS, CL, HAC | LTFS, TF, HTC, ND)
# (IS ⟂ LTMS, DI | LTFS, TF, HTC, HAC)
# (IS ⟂ LTMS, CL, ND, IC, HAC | LTFS, HTC, DI, EW)
# (IS ⟂ EW, LTMS, CL, ND, HAC | LTFS, IC, HTC, DI)
# (IS ⟂ EW, LTMS, CL, IC, HAC | LTFS, HTC, DI, ND)
# (IS ⟂ EW, LTMS, CL, ND, IC | LTFS, HTC, DI, HAC)
# (IS ⟂ DI, LTMS, CL, ND, HAC | LTFS, IC, HTC, EW)
# (IS ⟂ DI, LTMS, CL, IC, HAC | LTFS, HTC, ND, EW)
# (IS ⟂ DI, LTMS, CL, ND, IC | LTFS, HTC, HAC, EW)
# (IS ⟂ DI, EW, LTMS, CL, HAC | LTFS, IC, HTC, ND)
# (IS ⟂ DI, EW, LTMS, CL, ND | LTFS, IC, HTC, HAC)
# (IS ⟂ DI, EW, LTMS, CL, IC | LTFS, HTC, HAC, ND)
# (IS ⟂ LTFS, LTMS, HAC | TF, HTC, DI, EW)
# (IS ⟂ LTFS, LTMS, HAC | TF, IC, HTC, DI)
# (IS ⟂ LTFS, EW, LTMS, CL, HAC | TF, HTC, DI, ND)
# (IS ⟂ LTFS, LTMS | TF, HTC, DI, HAC)
# (IS ⟂ LTFS, LTMS, DI, HAC | TF, IC, HTC, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, HAC | TF, HTC, ND, EW)
# (IS ⟂ LTFS, LTMS, DI | TF, HTC, HAC, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, CL, HAC | TF, IC, HTC, ND)
# (IS ⟂ LTFS, LTMS, DI | TF, IC, HTC, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, CL | TF, HTC, HAC, ND)
# (IS ⟂ LTFS, LTMS, CL, ND, HAC | IC, HTC, DI, EW)
# (IS ⟂ LTFS, LTMS, CL, IC, HAC | HTC, DI, ND, EW)
# (IS ⟂ LTFS, LTMS, CL, ND, IC | HTC, DI, HAC, EW)
# (IS ⟂ LTFS, EW, LTMS, CL, HAC | IC, HTC, DI, ND)
# (IS ⟂ LTFS, EW, LTMS, CL, ND | IC, HTC, DI, HAC)
# (IS ⟂ LTFS, EW, LTMS, CL, IC | HTC, DI, HAC, ND)
# (IS ⟂ LTFS, DI, LTMS, CL, HAC | IC, HTC, ND, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, ND | IC, HTC, HAC, EW)
# (IS ⟂ LTFS, DI, LTMS, CL, IC | HAC, HTC, ND, EW)
# (IS ⟂ LTFS, DI, EW, LTMS, CL | IC, HTC, HAC, ND)
# (IS ⟂ CL, EW | LTFS, TF, ND, DI)
# (IS ⟂ CL | LTFS, TF, ND, EW)
# (IS ⟂ CL, EW | LTFS, IC, TF, ND)
# (IS ⟂ CL, EW | LTFS, TF, ND, HAC)
# (IS ⟂ LTMS, CL, HTC, HAC, ND | LTFS, IC, DI, EW)
# (IS ⟂ LTMS, CL, HTC, IC, HAC | LTFS, ND, DI, EW)
# (IS ⟂ LTMS, CL, HTC, IC, ND | LTFS, DI, HAC, EW)
# (IS ⟂ EW, LTMS, CL, HTC, HAC | LTFS, IC, ND, DI)
# (IS ⟂ EW, LTMS, CL, HTC, ND | LTFS, IC, DI, HAC)
# (IS ⟂ EW, LTMS, CL, HTC, IC | LTFS, ND, DI, HAC)
# (IS ⟂ DI, LTMS, CL, HTC, HAC | LTFS, IC, ND, EW)
# (IS ⟂ DI, LTMS, CL, HTC, ND | LTFS, IC, HAC, EW)
# (IS ⟂ DI, LTMS, CL, HTC, IC | LTFS, ND, HAC, EW)
# (IS ⟂ DI, EW, LTMS, CL, HTC | LTFS, IC, ND, HAC)
# (IS ⟂ CL | TF, ND, DI, EW)
# (IS ⟂ CL, EW | TF, IC, ND, DI)
# (IS ⟂ CL, EW | TF, ND, DI, HAC)
# (IS ⟂ CL | TF, IC, ND, EW)
# (IS ⟂ CL | TF, ND, HAC, EW)
# (IS ⟂ CL, EW | TF, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, HTC, HAC | IC, ND, DI, EW)
# (IS ⟂ LTFS, LTMS, CL, HTC, ND | IC, DI, HAC, EW)
# (IS ⟂ LTFS, LTMS, CL, HTC, IC | ND, DI, HAC, EW)
# (IS ⟂ LTFS, EW, LTMS, CL, HTC | IC, ND, DI, HAC)
# (IS ⟂ LTFS, DI, LTMS, CL, HTC | IC, ND, HAC, EW)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, TF)
# (IS ⟂ IC, ND, HAC, EW | LTMS, CL, HTC, LTFS, DI)
# (IS ⟂ IC, ND, DI, HAC | LTMS, CL, HTC, LTFS, EW)
# (IS ⟂ ND, DI, HAC, EW | LTMS, CL, HTC, LTFS, IC)
# (IS ⟂ IC, DI, HAC, EW | LTMS, CL, HTC, LTFS, ND)
# (IS ⟂ IC, ND, DI, EW | LTMS, CL, HTC, LTFS, HAC)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, TF, DI)
# (IS ⟂ LTFS, DI, HAC | LTMS, CL, HTC, TF, EW)
# (IS ⟂ LTFS, DI, HAC | LTMS, CL, HTC, TF, IC)
# (IS ⟂ LTFS, DI, HAC, EW | LTMS, CL, HTC, TF, ND)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, TF, HAC)
# (IS ⟂ LTFS, IC, ND, HAC | LTMS, CL, HTC, DI, EW)
# (IS ⟂ LTFS, ND, HAC, EW | LTMS, CL, HTC, DI, IC)
# (IS ⟂ LTFS, IC, HAC, EW | LTMS, CL, HTC, DI, ND)
# (IS ⟂ LTFS, IC, ND, EW | LTMS, CL, HTC, DI, HAC)
# (IS ⟂ LTFS, ND, DI, HAC | LTMS, CL, HTC, EW, IC)
# (IS ⟂ LTFS, IC, DI, HAC | LTMS, CL, HTC, EW, ND)
# (IS ⟂ LTFS, IC, ND, DI | LTMS, CL, HTC, EW, HAC)
# (IS ⟂ LTFS, DI, HAC, EW | LTMS, CL, HTC, IC, ND)
# (IS ⟂ LTFS, ND, DI, EW | LTMS, CL, HTC, IC, HAC)
# (IS ⟂ LTFS, IC, DI, EW | LTMS, CL, HTC, ND, HAC)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, ND)
# (IS ⟂ IC, HTC, HAC, ND | LTMS, CL, LTFS, DI, EW)
# (IS ⟂ HAC, HTC, ND, EW | LTMS, CL, LTFS, DI, IC)
# (IS ⟂ IC, HTC, HAC, EW | LTMS, CL, LTFS, DI, ND)
# (IS ⟂ IC, HTC, ND, EW | LTMS, CL, LTFS, DI, HAC)
# (IS ⟂ HTC, DI, HAC, ND | LTMS, CL, LTFS, EW, IC)
# (IS ⟂ IC, HTC, DI, HAC | LTMS, CL, LTFS, EW, ND)
# (IS ⟂ IC, HTC, DI, ND | LTMS, CL, LTFS, EW, HAC)
# (IS ⟂ HTC, DI, HAC, EW | LTMS, CL, LTFS, IC, ND)
# (IS ⟂ HTC, DI, ND, EW | LTMS, CL, LTFS, IC, HAC)
# (IS ⟂ IC, HTC, DI, EW | LTMS, CL, LTFS, ND, HAC)
# (IS ⟂ EW | LTMS, CL, TF, DI, ND)
# (IS ⟂ EW | LTMS, CL, TF, IC, ND)
# (IS ⟂ EW | LTMS, CL, TF, ND, HAC)
# (IS ⟂ LTFS, HTC, HAC, ND | LTMS, CL, DI, EW, IC)
# (IS ⟂ LTFS, IC, HTC, HAC | LTMS, CL, DI, EW, ND)
# (IS ⟂ LTFS, IC, HTC, ND | LTMS, CL, DI, EW, HAC)
# (IS ⟂ LTFS, HTC, HAC, EW | LTMS, CL, DI, IC, ND)
# (IS ⟂ LTFS, HTC, ND, EW | LTMS, CL, DI, IC, HAC)
# (IS ⟂ LTFS, IC, HTC, EW | LTMS, CL, DI, ND, HAC)
# (IS ⟂ LTFS, HTC, DI, HAC | LTMS, CL, EW, IC, ND)
# (IS ⟂ LTFS, HTC, DI, ND | LTMS, CL, EW, IC, HAC)
# (IS ⟂ LTFS, IC, HTC, DI | LTMS, CL, EW, ND, HAC)
# (IS ⟂ LTFS, HTC, DI, EW | LTMS, CL, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, HTC, LTFS, TF, DI)
# (IS ⟂ DI, HAC | LTMS, HTC, LTFS, TF, EW)
# (IS ⟂ DI, HAC | LTMS, HTC, LTFS, TF, IC)
# (IS ⟂ CL, DI, HAC, EW | LTMS, HTC, LTFS, TF, ND)
# (IS ⟂ DI | LTMS, HTC, LTFS, TF, HAC)
# (IS ⟂ IC, CL, ND, HAC | LTMS, HTC, LTFS, DI, EW)
# (IS ⟂ CL, ND, HAC, EW | LTMS, HTC, LTFS, DI, IC)
# (IS ⟂ IC, CL, HAC, EW | LTMS, HTC, LTFS, DI, ND)
# (IS ⟂ IC, CL, ND, EW | LTMS, HTC, LTFS, DI, HAC)
# (IS ⟂ CL, ND, DI, HAC | LTMS, HTC, LTFS, EW, IC)
# (IS ⟂ IC, CL, DI, HAC | LTMS, HTC, LTFS, EW, ND)
# (IS ⟂ IC, CL, ND, DI | LTMS, HTC, LTFS, EW, HAC)
# (IS ⟂ CL, DI, HAC, EW | LTMS, HTC, LTFS, IC, ND)
# (IS ⟂ CL, ND, DI, EW | LTMS, HTC, LTFS, IC, HAC)
# (IS ⟂ IC, CL, DI, EW | LTMS, HTC, LTFS, ND, HAC)
# (IS ⟂ LTFS, HAC | LTMS, HTC, TF, DI, EW)
# (IS ⟂ LTFS, HAC | LTMS, HTC, TF, DI, IC)
# (IS ⟂ LTFS, CL, HAC, EW | LTMS, HTC, TF, DI, ND)
# (IS ⟂ LTFS | LTMS, HTC, TF, DI, HAC)
# (IS ⟂ LTFS, DI, HAC | LTMS, HTC, TF, EW, IC)
# (IS ⟂ LTFS, CL, DI, HAC | LTMS, HTC, TF, EW, ND)
# (IS ⟂ LTFS, DI | LTMS, HTC, TF, EW, HAC)
# (IS ⟂ LTFS, DI, EW, CL, HAC | LTMS, HTC, TF, IC, ND)
# (IS ⟂ LTFS, DI | LTMS, HTC, TF, IC, HAC)
# (IS ⟂ LTFS, CL, DI, EW | LTMS, HTC, TF, ND, HAC)
# (IS ⟂ LTFS, CL, ND, HAC | LTMS, HTC, DI, EW, IC)
# (IS ⟂ LTFS, IC, CL, HAC | LTMS, HTC, DI, EW, ND)
# (IS ⟂ LTFS, IC, CL, ND | LTMS, HTC, DI, EW, HAC)
# (IS ⟂ LTFS, CL, HAC, EW | LTMS, HTC, DI, IC, ND)
# (IS ⟂ LTFS, CL, ND, EW | LTMS, HTC, DI, IC, HAC)
# (IS ⟂ LTFS, IC, CL, EW | LTMS, HTC, DI, ND, HAC)
# (IS ⟂ LTFS, CL, DI, HAC | LTMS, HTC, EW, IC, ND)
# (IS ⟂ LTFS, CL, ND, DI | LTMS, HTC, EW, IC, HAC)
# (IS ⟂ LTFS, IC, CL, DI | LTMS, HTC, EW, ND, HAC)
# (IS ⟂ LTFS, CL, DI, EW | LTMS, HTC, IC, ND, HAC)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, DI, ND)
# (IS ⟂ CL | LTMS, LTFS, TF, EW, ND)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, IC, ND)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, ND, HAC)
# (IS ⟂ CL, HTC, HAC, ND | LTMS, LTFS, DI, EW, IC)
# (IS ⟂ IC, CL, HTC, HAC | LTMS, LTFS, DI, EW, ND)
# (IS ⟂ IC, CL, HTC, ND | LTMS, LTFS, DI, EW, HAC)
# (IS ⟂ CL, HTC, HAC, EW | LTMS, LTFS, DI, IC, ND)
# (IS ⟂ CL, HTC, ND, EW | LTMS, LTFS, DI, IC, HAC)
# (IS ⟂ IC, CL, HTC, EW | LTMS, LTFS, DI, ND, HAC)
# (IS ⟂ CL, HTC, DI, HAC | LTMS, LTFS, EW, IC, ND)
# (IS ⟂ CL, HTC, DI, ND | LTMS, LTFS, EW, IC, HAC)
# (IS ⟂ IC, CL, HTC, DI | LTMS, LTFS, EW, ND, HAC)
# (IS ⟂ CL, HTC, DI, EW | LTMS, LTFS, IC, ND, HAC)
# (IS ⟂ CL | LTMS, TF, DI, EW, ND)
# (IS ⟂ CL, EW | LTMS, TF, DI, IC, ND)
# (IS ⟂ CL, EW | LTMS, TF, DI, ND, HAC)
# (IS ⟂ CL | LTMS, TF, EW, IC, ND)
# (IS ⟂ CL | LTMS, TF, EW, ND, HAC)
# (IS ⟂ CL, EW | LTMS, TF, IC, ND, HAC)
# (IS ⟂ LTFS, CL, HTC, HAC | LTMS, DI, EW, IC, ND)
# (IS ⟂ LTFS, CL, HTC, ND | LTMS, DI, EW, IC, HAC)
# (IS ⟂ LTFS, IC, CL, HTC | LTMS, DI, EW, ND, HAC)
# (IS ⟂ LTFS, CL, HTC, EW | LTMS, DI, IC, ND, HAC)
# (IS ⟂ LTFS, CL, HTC, DI | LTMS, EW, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, TF, DI)
# (IS ⟂ LTMS, DI, HAC | CL, HTC, LTFS, TF, EW)
# (IS ⟂ LTMS, DI, HAC | CL, HTC, LTFS, TF, IC)
# (IS ⟂ LTMS, DI, HAC, EW | CL, HTC, LTFS, TF, ND)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, TF, HAC)
# (IS ⟂ LTMS, ND, IC, HAC | CL, HTC, LTFS, DI, EW)
# (IS ⟂ LTMS, ND, HAC, EW | CL, HTC, LTFS, DI, IC)
# (IS ⟂ LTMS, HAC, IC, EW | CL, HTC, LTFS, DI, ND)
# (IS ⟂ LTMS, ND, IC, EW | CL, HTC, LTFS, DI, HAC)
# (IS ⟂ LTMS, ND, DI, HAC | CL, HTC, LTFS, EW, IC)
# (IS ⟂ LTMS, DI, IC, HAC | CL, HTC, LTFS, EW, ND)
# (IS ⟂ LTMS, ND, DI, IC | CL, HTC, LTFS, EW, HAC)
# (IS ⟂ LTMS, DI, HAC, EW | CL, HTC, LTFS, IC, ND)
# (IS ⟂ LTMS, ND, DI, EW | CL, HTC, LTFS, IC, HAC)
# (IS ⟂ LTMS, DI, IC, EW | CL, HTC, LTFS, ND, HAC)
# (IS ⟂ LTFS, LTMS, HAC | CL, HTC, TF, DI, EW)
# (IS ⟂ LTFS, LTMS, HAC | CL, HTC, TF, DI, IC)
# (IS ⟂ LTFS, LTMS, HAC, EW | CL, HTC, TF, DI, ND)
# (IS ⟂ LTFS, LTMS | CL, HTC, TF, DI, HAC)
# (IS ⟂ LTFS, LTMS, DI, HAC | CL, HTC, TF, EW, IC)
# (IS ⟂ LTFS, LTMS, DI, HAC | CL, HTC, TF, EW, ND)
# (IS ⟂ LTFS, LTMS, DI | CL, HTC, TF, EW, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, HAC | CL, HTC, TF, IC, ND)
# (IS ⟂ LTFS, LTMS, DI | CL, HTC, TF, IC, HAC)
# (IS ⟂ LTFS, LTMS, DI, EW | CL, HTC, TF, ND, HAC)
# (IS ⟂ LTFS, LTMS, ND, HAC | CL, HTC, DI, EW, IC)
# (IS ⟂ LTFS, LTMS, IC, HAC | CL, HTC, DI, EW, ND)
# (IS ⟂ LTFS, LTMS, ND, IC | CL, HTC, DI, EW, HAC)
# (IS ⟂ LTFS, LTMS, HAC, EW | CL, HTC, DI, IC, ND)
# (IS ⟂ LTFS, LTMS, ND, EW | CL, HTC, DI, IC, HAC)
# (IS ⟂ LTFS, LTMS, IC, EW | CL, HTC, DI, ND, HAC)
# (IS ⟂ LTFS, LTMS, DI, HAC | CL, HTC, EW, IC, ND)
# (IS ⟂ LTFS, LTMS, ND, DI | CL, HTC, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, DI, IC | CL, HTC, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, DI, EW | CL, HTC, IC, ND, HAC)
# (IS ⟂ EW | CL, LTFS, TF, DI, ND)
# (IS ⟂ EW | CL, LTFS, TF, IC, ND)
# (IS ⟂ EW | CL, LTFS, TF, ND, HAC)
# (IS ⟂ LTMS, HTC, HAC, ND | CL, LTFS, DI, EW, IC)
# (IS ⟂ LTMS, HTC, IC, HAC | CL, LTFS, DI, EW, ND)
# (IS ⟂ LTMS, HTC, IC, ND | CL, LTFS, DI, EW, HAC)
# (IS ⟂ LTMS, HTC, HAC, EW | CL, LTFS, DI, IC, ND)
# (IS ⟂ LTMS, HTC, ND, EW | CL, LTFS, DI, IC, HAC)
# (IS ⟂ LTMS, HTC, IC, EW | CL, LTFS, DI, ND, HAC)
# (IS ⟂ LTMS, HTC, DI, HAC | CL, LTFS, EW, IC, ND)
# (IS ⟂ LTMS, HTC, DI, ND | CL, LTFS, EW, IC, HAC)
# (IS ⟂ LTMS, HTC, DI, IC | CL, LTFS, EW, ND, HAC)
# (IS ⟂ LTMS, HTC, DI, EW | CL, LTFS, IC, ND, HAC)
# (IS ⟂ EW | CL, TF, DI, IC, ND)
# (IS ⟂ EW | CL, TF, DI, ND, HAC)
# (IS ⟂ EW | CL, TF, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HTC, HAC | CL, DI, EW, IC, ND)
# (IS ⟂ LTFS, LTMS, HTC, ND | CL, DI, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, HTC, IC | CL, DI, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, HTC, EW | CL, DI, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HTC, DI | CL, EW, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | HTC, LTFS, TF, DI, EW)
# (IS ⟂ LTMS, HAC | HTC, LTFS, TF, DI, IC)
# (IS ⟂ LTMS, CL, HAC, EW | HTC, LTFS, TF, DI, ND)
# (IS ⟂ LTMS | HTC, LTFS, TF, DI, HAC)
# (IS ⟂ LTMS, DI, HAC | HTC, LTFS, TF, EW, IC)
# (IS ⟂ LTMS, CL, DI, HAC | HTC, LTFS, TF, EW, ND)
# (IS ⟂ LTMS, DI | HTC, LTFS, TF, EW, HAC)
# (IS ⟂ DI, EW, LTMS, CL, HAC | HTC, LTFS, TF, IC, ND)
# (IS ⟂ LTMS, DI | HTC, LTFS, TF, IC, HAC)
# (IS ⟂ LTMS, CL, DI, EW | HTC, LTFS, TF, ND, HAC)
# (IS ⟂ LTMS, CL, ND, HAC | HTC, LTFS, DI, EW, IC)
# (IS ⟂ LTMS, CL, IC, HAC | HTC, LTFS, DI, EW, ND)
# (IS ⟂ LTMS, CL, ND, IC | HTC, LTFS, DI, EW, HAC)
# (IS ⟂ LTMS, CL, HAC, EW | HTC, LTFS, DI, IC, ND)
# (IS ⟂ LTMS, CL, ND, EW | HTC, LTFS, DI, IC, HAC)
# (IS ⟂ LTMS, CL, IC, EW | HTC, LTFS, DI, ND, HAC)
# (IS ⟂ LTMS, CL, DI, HAC | HTC, LTFS, EW, IC, ND)
# (IS ⟂ LTMS, CL, ND, DI | HTC, LTFS, EW, IC, HAC)
# (IS ⟂ LTMS, CL, DI, IC | HTC, LTFS, EW, ND, HAC)
# (IS ⟂ LTMS, CL, DI, EW | HTC, LTFS, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HAC | HTC, TF, DI, EW, IC)
# (IS ⟂ LTFS, LTMS, CL, HAC | HTC, TF, DI, EW, ND)
# (IS ⟂ LTFS, LTMS | HTC, TF, DI, EW, HAC)
# (IS ⟂ LTFS, EW, LTMS, CL, HAC | HTC, TF, DI, IC, ND)
# (IS ⟂ LTFS, LTMS | HTC, TF, DI, IC, HAC)
# (IS ⟂ LTFS, LTMS, CL, EW | HTC, TF, DI, ND, HAC)
# (IS ⟂ LTFS, DI, LTMS, CL, HAC | HTC, TF, EW, IC, ND)
# (IS ⟂ LTFS, LTMS, DI | HTC, TF, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, CL, DI | HTC, TF, EW, ND, HAC)
# (IS ⟂ LTFS, DI, EW, LTMS, CL | HTC, TF, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, HAC | HTC, DI, EW, IC, ND)
# (IS ⟂ LTFS, LTMS, CL, ND | HTC, DI, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, CL, IC | HTC, DI, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, EW | HTC, DI, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, DI | HTC, EW, IC, ND, HAC)
# (IS ⟂ CL | LTFS, TF, DI, EW, ND)
# (IS ⟂ CL, EW | LTFS, TF, DI, IC, ND)
# (IS ⟂ CL, EW | LTFS, TF, DI, ND, HAC)
# (IS ⟂ CL | LTFS, TF, EW, IC, ND)
# (IS ⟂ CL | LTFS, TF, EW, ND, HAC)
# (IS ⟂ CL, EW | LTFS, TF, IC, ND, HAC)
# (IS ⟂ LTMS, CL, HTC, HAC | LTFS, DI, EW, IC, ND)
# (IS ⟂ LTMS, CL, HTC, ND | LTFS, DI, EW, IC, HAC)
# (IS ⟂ LTMS, CL, HTC, IC | LTFS, DI, EW, ND, HAC)
# (IS ⟂ LTMS, CL, HTC, EW | LTFS, DI, IC, ND, HAC)
# (IS ⟂ LTMS, CL, HTC, DI | LTFS, EW, IC, ND, HAC)
# (IS ⟂ CL | TF, DI, EW, IC, ND)
# (IS ⟂ CL | TF, DI, EW, ND, HAC)
# (IS ⟂ CL, EW | TF, DI, IC, ND, HAC)
# (IS ⟂ CL | TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, HTC | DI, EW, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, TF, DI)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, TF, EW)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, TF, IC)
# (IS ⟂ DI, HAC, EW | LTMS, CL, HTC, LTFS, TF, ND)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, TF, HAC)
# (IS ⟂ IC, ND, HAC | LTMS, CL, HTC, LTFS, DI, EW)
# (IS ⟂ ND, HAC, EW | LTMS, CL, HTC, LTFS, DI, IC)
# (IS ⟂ IC, HAC, EW | LTMS, CL, HTC, LTFS, DI, ND)
# (IS ⟂ IC, ND, EW | LTMS, CL, HTC, LTFS, DI, HAC)
# (IS ⟂ ND, DI, HAC | LTMS, CL, HTC, LTFS, EW, IC)
# (IS ⟂ IC, DI, HAC | LTMS, CL, HTC, LTFS, EW, ND)
# (IS ⟂ IC, ND, DI | LTMS, CL, HTC, LTFS, EW, HAC)
# (IS ⟂ DI, HAC, EW | LTMS, CL, HTC, LTFS, IC, ND)
# (IS ⟂ ND, DI, EW | LTMS, CL, HTC, LTFS, IC, HAC)
# (IS ⟂ IC, DI, EW | LTMS, CL, HTC, LTFS, ND, HAC)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, TF, DI, EW)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, TF, DI, IC)
# (IS ⟂ LTFS, HAC, EW | LTMS, CL, HTC, TF, DI, ND)
# (IS ⟂ LTFS | LTMS, CL, HTC, TF, DI, HAC)
# (IS ⟂ LTFS, DI, HAC | LTMS, CL, HTC, TF, EW, IC)
# (IS ⟂ LTFS, DI, HAC | LTMS, CL, HTC, TF, EW, ND)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, TF, EW, HAC)
# (IS ⟂ LTFS, DI, HAC, EW | LTMS, CL, HTC, TF, IC, ND)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, TF, IC, HAC)
# (IS ⟂ LTFS, DI, EW | LTMS, CL, HTC, TF, ND, HAC)
# (IS ⟂ LTFS, ND, HAC | LTMS, CL, HTC, DI, EW, IC)
# (IS ⟂ LTFS, IC, HAC | LTMS, CL, HTC, DI, EW, ND)
# (IS ⟂ LTFS, IC, ND | LTMS, CL, HTC, DI, EW, HAC)
# (IS ⟂ LTFS, HAC, EW | LTMS, CL, HTC, DI, IC, ND)
# (IS ⟂ LTFS, ND, EW | LTMS, CL, HTC, DI, IC, HAC)
# (IS ⟂ LTFS, IC, EW | LTMS, CL, HTC, DI, ND, HAC)
# (IS ⟂ LTFS, DI, HAC | LTMS, CL, HTC, EW, IC, ND)
# (IS ⟂ LTFS, ND, DI | LTMS, CL, HTC, EW, IC, HAC)
# (IS ⟂ LTFS, IC, DI | LTMS, CL, HTC, EW, ND, HAC)
# (IS ⟂ LTFS, DI, EW | LTMS, CL, HTC, IC, ND, HAC)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, DI, ND)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, IC, ND)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, ND, HAC)
# (IS ⟂ HTC, HAC, ND | LTMS, CL, LTFS, DI, EW, IC)
# (IS ⟂ IC, HTC, HAC | LTMS, CL, LTFS, DI, EW, ND)
# (IS ⟂ IC, HTC, ND | LTMS, CL, LTFS, DI, EW, HAC)
# (IS ⟂ HTC, HAC, EW | LTMS, CL, LTFS, DI, IC, ND)
# (IS ⟂ HTC, EW, ND | LTMS, CL, LTFS, DI, IC, HAC)
# (IS ⟂ IC, HTC, EW | LTMS, CL, LTFS, DI, ND, HAC)
# (IS ⟂ HTC, DI, HAC | LTMS, CL, LTFS, EW, IC, ND)
# (IS ⟂ HTC, DI, ND | LTMS, CL, LTFS, EW, IC, HAC)
# (IS ⟂ IC, HTC, DI | LTMS, CL, LTFS, EW, ND, HAC)
# (IS ⟂ HTC, DI, EW | LTMS, CL, LTFS, IC, ND, HAC)
# (IS ⟂ EW | LTMS, CL, TF, DI, IC, ND)
# (IS ⟂ EW | LTMS, CL, TF, DI, ND, HAC)
# (IS ⟂ EW | LTMS, CL, TF, IC, ND, HAC)
# (IS ⟂ LTFS, HTC, HAC | LTMS, CL, DI, EW, IC, ND)
# (IS ⟂ LTFS, HTC, ND | LTMS, CL, DI, EW, IC, HAC)
# (IS ⟂ LTFS, IC, HTC | LTMS, CL, DI, EW, ND, HAC)
# (IS ⟂ LTFS, HTC, EW | LTMS, CL, DI, IC, ND, HAC)
# (IS ⟂ LTFS, HTC, DI | LTMS, CL, EW, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, HTC, LTFS, TF, DI, EW)
# (IS ⟂ HAC | LTMS, HTC, LTFS, TF, DI, IC)
# (IS ⟂ CL, HAC, EW | LTMS, HTC, LTFS, TF, DI, ND)
# (IS ⟂ DI, HAC | LTMS, HTC, LTFS, TF, EW, IC)
# (IS ⟂ CL, DI, HAC | LTMS, HTC, LTFS, TF, EW, ND)
# (IS ⟂ DI | LTMS, HTC, LTFS, TF, EW, HAC)
# (IS ⟂ CL, DI, HAC, EW | LTMS, HTC, LTFS, TF, IC, ND)
# (IS ⟂ DI | LTMS, HTC, LTFS, TF, IC, HAC)
# (IS ⟂ CL, DI, EW | LTMS, HTC, LTFS, TF, ND, HAC)
# (IS ⟂ CL, ND, HAC | LTMS, HTC, LTFS, DI, EW, IC)
# (IS ⟂ IC, CL, HAC | LTMS, HTC, LTFS, DI, EW, ND)
# (IS ⟂ IC, CL, ND | LTMS, HTC, LTFS, DI, EW, HAC)
# (IS ⟂ CL, HAC, EW | LTMS, HTC, LTFS, DI, IC, ND)
# (IS ⟂ CL, ND, EW | LTMS, HTC, LTFS, DI, IC, HAC)
# (IS ⟂ IC, CL, EW | LTMS, HTC, LTFS, DI, ND, HAC)
# (IS ⟂ CL, DI, HAC | LTMS, HTC, LTFS, EW, IC, ND)
# (IS ⟂ CL, ND, DI | LTMS, HTC, LTFS, EW, IC, HAC)
# (IS ⟂ IC, CL, DI | LTMS, HTC, LTFS, EW, ND, HAC)
# (IS ⟂ CL, DI, EW | LTMS, HTC, LTFS, IC, ND, HAC)
# (IS ⟂ LTFS, HAC | LTMS, HTC, TF, DI, EW, IC)
# (IS ⟂ LTFS, CL, HAC | LTMS, HTC, TF, DI, EW, ND)
# (IS ⟂ LTFS | LTMS, HTC, TF, DI, EW, HAC)
# (IS ⟂ LTFS, CL, HAC, EW | LTMS, HTC, TF, DI, IC, ND)
# (IS ⟂ LTFS | LTMS, HTC, TF, DI, IC, HAC)
# (IS ⟂ LTFS, CL, EW | LTMS, HTC, TF, DI, ND, HAC)
# (IS ⟂ LTFS, CL, DI, HAC | LTMS, HTC, TF, EW, IC, ND)
# (IS ⟂ LTFS, DI | LTMS, HTC, TF, EW, IC, HAC)
# (IS ⟂ LTFS, CL, DI | LTMS, HTC, TF, EW, ND, HAC)
# (IS ⟂ LTFS, CL, DI, EW | LTMS, HTC, TF, IC, ND, HAC)
# (IS ⟂ LTFS, CL, HAC | LTMS, HTC, DI, EW, IC, ND)
# (IS ⟂ LTFS, CL, ND | LTMS, HTC, DI, EW, IC, HAC)
# (IS ⟂ LTFS, IC, CL | LTMS, HTC, DI, EW, ND, HAC)
# (IS ⟂ LTFS, CL, EW | LTMS, HTC, DI, IC, ND, HAC)
# (IS ⟂ LTFS, CL, DI | LTMS, HTC, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, LTFS, TF, DI, EW, ND)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, DI, IC, ND)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, DI, ND, HAC)
# (IS ⟂ CL | LTMS, LTFS, TF, EW, IC, ND)
# (IS ⟂ CL | LTMS, LTFS, TF, EW, ND, HAC)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, IC, ND, HAC)
# (IS ⟂ CL, HTC, HAC | LTMS, LTFS, DI, EW, IC, ND)
# (IS ⟂ CL, HTC, ND | LTMS, LTFS, DI, EW, IC, HAC)
# (IS ⟂ IC, CL, HTC | LTMS, LTFS, DI, EW, ND, HAC)
# (IS ⟂ CL, HTC, EW | LTMS, LTFS, DI, IC, ND, HAC)
# (IS ⟂ CL, HTC, DI | LTMS, LTFS, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, TF, DI, EW, IC, ND)
# (IS ⟂ CL | LTMS, TF, DI, EW, ND, HAC)
# (IS ⟂ CL, EW | LTMS, TF, DI, IC, ND, HAC)
# (IS ⟂ CL | LTMS, TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS, CL, HTC | LTMS, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, TF, DI, EW)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, TF, DI, IC)
# (IS ⟂ LTMS, HAC, EW | CL, HTC, LTFS, TF, DI, ND)
# (IS ⟂ LTMS | CL, HTC, LTFS, TF, DI, HAC)
# (IS ⟂ LTMS, DI, HAC | CL, HTC, LTFS, TF, EW, IC)
# (IS ⟂ LTMS, DI, HAC | CL, HTC, LTFS, TF, EW, ND)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, TF, EW, HAC)
# (IS ⟂ LTMS, DI, HAC, EW | CL, HTC, LTFS, TF, IC, ND)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, TF, IC, HAC)
# (IS ⟂ LTMS, DI, EW | CL, HTC, LTFS, TF, ND, HAC)
# (IS ⟂ LTMS, ND, HAC | CL, HTC, LTFS, DI, EW, IC)
# (IS ⟂ LTMS, IC, HAC | CL, HTC, LTFS, DI, EW, ND)
# (IS ⟂ LTMS, ND, IC | CL, HTC, LTFS, DI, EW, HAC)
# (IS ⟂ LTMS, HAC, EW | CL, HTC, LTFS, DI, IC, ND)
# (IS ⟂ LTMS, ND, EW | CL, HTC, LTFS, DI, IC, HAC)
# (IS ⟂ LTMS, IC, EW | CL, HTC, LTFS, DI, ND, HAC)
# (IS ⟂ LTMS, DI, HAC | CL, HTC, LTFS, EW, IC, ND)
# (IS ⟂ LTMS, ND, DI | CL, HTC, LTFS, EW, IC, HAC)
# (IS ⟂ LTMS, DI, IC | CL, HTC, LTFS, EW, ND, HAC)
# (IS ⟂ LTMS, DI, EW | CL, HTC, LTFS, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HAC | CL, HTC, TF, DI, EW, IC)
# (IS ⟂ LTFS, LTMS, HAC | CL, HTC, TF, DI, EW, ND)
# (IS ⟂ LTFS, LTMS | CL, HTC, TF, DI, EW, HAC)
# (IS ⟂ LTFS, LTMS, HAC, EW | CL, HTC, TF, DI, IC, ND)
# (IS ⟂ LTFS, LTMS | CL, HTC, TF, DI, IC, HAC)
# (IS ⟂ LTFS, LTMS, EW | CL, HTC, TF, DI, ND, HAC)
# (IS ⟂ LTFS, LTMS, DI, HAC | CL, HTC, TF, EW, IC, ND)
# (IS ⟂ LTFS, LTMS, DI | CL, HTC, TF, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, DI | CL, HTC, TF, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, DI, EW | CL, HTC, TF, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HAC | CL, HTC, DI, EW, IC, ND)
# (IS ⟂ LTFS, LTMS, ND | CL, HTC, DI, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, IC | CL, HTC, DI, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, EW | CL, HTC, DI, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, DI | CL, HTC, EW, IC, ND, HAC)
# (IS ⟂ EW | CL, LTFS, TF, DI, IC, ND)
# (IS ⟂ EW | CL, LTFS, TF, DI, ND, HAC)
# (IS ⟂ EW | CL, LTFS, TF, IC, ND, HAC)
# (IS ⟂ LTMS, HTC, HAC | CL, LTFS, DI, EW, IC, ND)
# (IS ⟂ LTMS, HTC, ND | CL, LTFS, DI, EW, IC, HAC)
# (IS ⟂ LTMS, HTC, IC | CL, LTFS, DI, EW, ND, HAC)
# (IS ⟂ LTMS, HTC, EW | CL, LTFS, DI, IC, ND, HAC)
# (IS ⟂ LTMS, HTC, DI | CL, LTFS, EW, IC, ND, HAC)
# (IS ⟂ EW | CL, TF, DI, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HTC | CL, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | HTC, LTFS, TF, DI, EW, IC)
# (IS ⟂ LTMS, CL, HAC | HTC, LTFS, TF, DI, EW, ND)
# (IS ⟂ LTMS | HTC, LTFS, TF, DI, EW, HAC)
# (IS ⟂ LTMS, CL, HAC, EW | HTC, LTFS, TF, DI, IC, ND)
# (IS ⟂ LTMS | HTC, LTFS, TF, DI, IC, HAC)
# (IS ⟂ LTMS, CL, EW | HTC, LTFS, TF, DI, ND, HAC)
# (IS ⟂ LTMS, CL, DI, HAC | HTC, LTFS, TF, EW, IC, ND)
# (IS ⟂ LTMS, DI | HTC, LTFS, TF, EW, IC, HAC)
# (IS ⟂ LTMS, CL, DI | HTC, LTFS, TF, EW, ND, HAC)
# (IS ⟂ LTMS, CL, DI, EW | HTC, LTFS, TF, IC, ND, HAC)
# (IS ⟂ LTMS, CL, HAC | HTC, LTFS, DI, EW, IC, ND)
# (IS ⟂ LTMS, CL, ND | HTC, LTFS, DI, EW, IC, HAC)
# (IS ⟂ LTMS, CL, IC | HTC, LTFS, DI, EW, ND, HAC)
# (IS ⟂ LTMS, CL, EW | HTC, LTFS, DI, IC, ND, HAC)
# (IS ⟂ LTMS, CL, DI | HTC, LTFS, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, HAC | HTC, TF, DI, EW, IC, ND)
# (IS ⟂ LTFS, LTMS | HTC, TF, DI, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS, CL | HTC, TF, DI, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, EW | HTC, TF, DI, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL, DI | HTC, TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL | HTC, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | LTFS, TF, DI, EW, IC, ND)
# (IS ⟂ CL | LTFS, TF, DI, EW, ND, HAC)
# (IS ⟂ CL, EW | LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ CL | LTFS, TF, EW, IC, ND, HAC)
# (IS ⟂ LTMS, CL, HTC | LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | TF, DI, EW, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, TF, DI, EW)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, TF, DI, IC)
# (IS ⟂ HAC, EW | LTMS, CL, HTC, LTFS, TF, DI, ND)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, TF, EW, IC)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, TF, EW, ND)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, TF, EW, HAC)
# (IS ⟂ DI, HAC, EW | LTMS, CL, HTC, LTFS, TF, IC, ND)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, TF, IC, HAC)
# (IS ⟂ DI, EW | LTMS, CL, HTC, LTFS, TF, ND, HAC)
# (IS ⟂ ND, HAC | LTMS, CL, HTC, LTFS, DI, EW, IC)
# (IS ⟂ IC, HAC | LTMS, CL, HTC, LTFS, DI, EW, ND)
# (IS ⟂ IC, ND | LTMS, CL, HTC, LTFS, DI, EW, HAC)
# (IS ⟂ HAC, EW | LTMS, CL, HTC, LTFS, DI, IC, ND)
# (IS ⟂ ND, EW | LTMS, CL, HTC, LTFS, DI, IC, HAC)
# (IS ⟂ IC, EW | LTMS, CL, HTC, LTFS, DI, ND, HAC)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, EW, IC, ND)
# (IS ⟂ ND, DI | LTMS, CL, HTC, LTFS, EW, IC, HAC)
# (IS ⟂ IC, DI | LTMS, CL, HTC, LTFS, EW, ND, HAC)
# (IS ⟂ DI, EW | LTMS, CL, HTC, LTFS, IC, ND, HAC)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, TF, DI, EW, IC)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, TF, DI, EW, ND)
# (IS ⟂ LTFS | LTMS, CL, HTC, TF, DI, EW, HAC)
# (IS ⟂ LTFS, HAC, EW | LTMS, CL, HTC, TF, DI, IC, ND)
# (IS ⟂ LTFS | LTMS, CL, HTC, TF, DI, IC, HAC)
# (IS ⟂ LTFS, EW | LTMS, CL, HTC, TF, DI, ND, HAC)
# (IS ⟂ LTFS, DI, HAC | LTMS, CL, HTC, TF, EW, IC, ND)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, TF, EW, IC, HAC)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, TF, EW, ND, HAC)
# (IS ⟂ LTFS, DI, EW | LTMS, CL, HTC, TF, IC, ND, HAC)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, DI, EW, IC, ND)
# (IS ⟂ LTFS, ND | LTMS, CL, HTC, DI, EW, IC, HAC)
# (IS ⟂ LTFS, IC | LTMS, CL, HTC, DI, EW, ND, HAC)
# (IS ⟂ LTFS, EW | LTMS, CL, HTC, DI, IC, ND, HAC)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, EW, IC, ND, HAC)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, DI, IC, ND)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, DI, ND, HAC)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, IC, ND, HAC)
# (IS ⟂ HTC, HAC | LTMS, CL, LTFS, DI, EW, IC, ND)
# (IS ⟂ HTC, ND | LTMS, CL, LTFS, DI, EW, IC, HAC)
# (IS ⟂ IC, HTC | LTMS, CL, LTFS, DI, EW, ND, HAC)
# (IS ⟂ HTC, EW | LTMS, CL, LTFS, DI, IC, ND, HAC)
# (IS ⟂ HTC, DI | LTMS, CL, LTFS, EW, IC, ND, HAC)
# (IS ⟂ EW | LTMS, CL, TF, DI, IC, ND, HAC)
# (IS ⟂ LTFS, HTC | LTMS, CL, DI, EW, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, HTC, LTFS, TF, DI, EW, IC)
# (IS ⟂ CL, HAC | LTMS, HTC, LTFS, TF, DI, EW, ND)
# (IS ⟂ CL, HAC, EW | LTMS, HTC, LTFS, TF, DI, IC, ND)
# (IS ⟂ CL, EW | LTMS, HTC, LTFS, TF, DI, ND, HAC)
# (IS ⟂ CL, DI, HAC | LTMS, HTC, LTFS, TF, EW, IC, ND)
# (IS ⟂ DI | LTMS, HTC, LTFS, TF, EW, IC, HAC)
# (IS ⟂ CL, DI | LTMS, HTC, LTFS, TF, EW, ND, HAC)
# (IS ⟂ CL, DI, EW | LTMS, HTC, LTFS, TF, IC, ND, HAC)
# (IS ⟂ CL, HAC | LTMS, HTC, LTFS, DI, EW, IC, ND)
# (IS ⟂ CL, ND | LTMS, HTC, LTFS, DI, EW, IC, HAC)
# (IS ⟂ IC, CL | LTMS, HTC, LTFS, DI, EW, ND, HAC)
# (IS ⟂ CL, EW | LTMS, HTC, LTFS, DI, IC, ND, HAC)
# (IS ⟂ CL, DI | LTMS, HTC, LTFS, EW, IC, ND, HAC)
# (IS ⟂ LTFS, CL, HAC | LTMS, HTC, TF, DI, EW, IC, ND)
# (IS ⟂ LTFS | LTMS, HTC, TF, DI, EW, IC, HAC)
# (IS ⟂ LTFS, CL | LTMS, HTC, TF, DI, EW, ND, HAC)
# (IS ⟂ LTFS, CL, EW | LTMS, HTC, TF, DI, IC, ND, HAC)
# (IS ⟂ LTFS, CL, DI | LTMS, HTC, TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS, CL | LTMS, HTC, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, LTFS, TF, DI, EW, IC, ND)
# (IS ⟂ CL | LTMS, LTFS, TF, DI, EW, ND, HAC)
# (IS ⟂ CL, EW | LTMS, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ CL | LTMS, LTFS, TF, EW, IC, ND, HAC)
# (IS ⟂ CL, HTC | LTMS, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, TF, DI, EW, IC)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, TF, DI, EW, ND)
# (IS ⟂ LTMS | CL, HTC, LTFS, TF, DI, EW, HAC)
# (IS ⟂ LTMS, HAC, EW | CL, HTC, LTFS, TF, DI, IC, ND)
# (IS ⟂ LTMS | CL, HTC, LTFS, TF, DI, IC, HAC)
# (IS ⟂ LTMS, EW | CL, HTC, LTFS, TF, DI, ND, HAC)
# (IS ⟂ LTMS, DI, HAC | CL, HTC, LTFS, TF, EW, IC, ND)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, TF, EW, IC, HAC)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, TF, EW, ND, HAC)
# (IS ⟂ LTMS, DI, EW | CL, HTC, LTFS, TF, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, DI, EW, IC, ND)
# (IS ⟂ LTMS, ND | CL, HTC, LTFS, DI, EW, IC, HAC)
# (IS ⟂ LTMS, IC | CL, HTC, LTFS, DI, EW, ND, HAC)
# (IS ⟂ LTMS, EW | CL, HTC, LTFS, DI, IC, ND, HAC)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, HAC | CL, HTC, TF, DI, EW, IC, ND)
# (IS ⟂ LTFS, LTMS | CL, HTC, TF, DI, EW, IC, HAC)
# (IS ⟂ LTFS, LTMS | CL, HTC, TF, DI, EW, ND, HAC)
# (IS ⟂ LTFS, LTMS, EW | CL, HTC, TF, DI, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, DI | CL, HTC, TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS | CL, HTC, DI, EW, IC, ND, HAC)
# (IS ⟂ EW | CL, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ LTMS, HTC | CL, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS, CL, HAC | HTC, LTFS, TF, DI, EW, IC, ND)
# (IS ⟂ LTMS | HTC, LTFS, TF, DI, EW, IC, HAC)
# (IS ⟂ LTMS, CL | HTC, LTFS, TF, DI, EW, ND, HAC)
# (IS ⟂ LTMS, CL, EW | HTC, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ LTMS, CL, DI | HTC, LTFS, TF, EW, IC, ND, HAC)
# (IS ⟂ LTMS, CL | HTC, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS, CL | HTC, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | LTFS, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, TF, DI, EW, IC)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, TF, DI, EW, ND)
# (IS ⟂ HAC, EW | LTMS, CL, HTC, LTFS, TF, DI, IC, ND)
# (IS ⟂ EW | LTMS, CL, HTC, LTFS, TF, DI, ND, HAC)
# (IS ⟂ DI, HAC | LTMS, CL, HTC, LTFS, TF, EW, IC, ND)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, TF, EW, IC, HAC)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, TF, EW, ND, HAC)
# (IS ⟂ DI, EW | LTMS, CL, HTC, LTFS, TF, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, DI, EW, IC, ND)
# (IS ⟂ ND | LTMS, CL, HTC, LTFS, DI, EW, IC, HAC)
# (IS ⟂ IC | LTMS, CL, HTC, LTFS, DI, EW, ND, HAC)
# (IS ⟂ EW | LTMS, CL, HTC, LTFS, DI, IC, ND, HAC)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, EW, IC, ND, HAC)
# (IS ⟂ LTFS, HAC | LTMS, CL, HTC, TF, DI, EW, IC, ND)
# (IS ⟂ LTFS | LTMS, CL, HTC, TF, DI, EW, IC, HAC)
# (IS ⟂ LTFS | LTMS, CL, HTC, TF, DI, EW, ND, HAC)
# (IS ⟂ LTFS, EW | LTMS, CL, HTC, TF, DI, IC, ND, HAC)
# (IS ⟂ LTFS, DI | LTMS, CL, HTC, TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS | LTMS, CL, HTC, DI, EW, IC, ND, HAC)
# (IS ⟂ EW | LTMS, CL, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ HTC | LTMS, CL, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ CL, HAC | LTMS, HTC, LTFS, TF, DI, EW, IC, ND)
# (IS ⟂ CL | LTMS, HTC, LTFS, TF, DI, EW, ND, HAC)
# (IS ⟂ CL, EW | LTMS, HTC, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ CL, DI | LTMS, HTC, LTFS, TF, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, HTC, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ LTFS, CL | LTMS, HTC, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, LTFS, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS, HAC | CL, HTC, LTFS, TF, DI, EW, IC, ND)
# (IS ⟂ LTMS | CL, HTC, LTFS, TF, DI, EW, IC, HAC)
# (IS ⟂ LTMS | CL, HTC, LTFS, TF, DI, EW, ND, HAC)
# (IS ⟂ LTMS, EW | CL, HTC, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ LTMS, DI | CL, HTC, LTFS, TF, EW, IC, ND, HAC)
# (IS ⟂ LTMS | CL, HTC, LTFS, DI, EW, IC, ND, HAC)
# (IS ⟂ LTFS, LTMS | CL, HTC, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS, CL | HTC, LTFS, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ HAC | LTMS, CL, HTC, LTFS, TF, DI, EW, IC, ND)
# (IS ⟂ EW | LTMS, CL, HTC, LTFS, TF, DI, IC, ND, HAC)
# (IS ⟂ DI | LTMS, CL, HTC, LTFS, TF, EW, IC, ND, HAC)
# (IS ⟂ LTFS | LTMS, CL, HTC, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ CL | LTMS, HTC, LTFS, TF, DI, EW, IC, ND, HAC)
# (IS ⟂ LTMS | CL, HTC, LTFS, TF, DI, EW, IC, ND, HAC)
# (LTMS ⟂ IS, CL, LTFS, DI, EW, IC, ND, HAC)
# (LTMS ⟂ LTFS, DI, EW, IC, CL, ND, HAC | IS)
# (LTMS ⟂ LTFS, IS, DI, EW, IC, ND, HAC | CL)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | HTC)
# (LTMS ⟂ IS, DI, EW, IC, CL, ND, HAC | LTFS)
# (LTMS ⟂ LTFS, IS, EW, IC, CL, ND, HAC | DI)
# (LTMS ⟂ LTFS, IS, DI, IC, CL, ND, HAC | EW)
# (LTMS ⟂ LTFS, IS, DI, EW, CL, ND, HAC | IC)
# (LTMS ⟂ LTFS, IS, DI, EW, IC, CL, HAC | ND)
# (LTMS ⟂ LTFS, IS, DI, EW, IC, CL, ND | HAC)
# (LTMS ⟂ LTFS, DI, EW, IC, ND, HAC | CL, IS)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS)
# (LTMS ⟂ DI, EW, IC, CL, ND, HAC | LTFS, IS)
# (LTMS ⟂ LTFS, EW, IC, CL, ND, HAC | IS, DI)
# (LTMS ⟂ LTFS, DI, IC, CL, ND, HAC | IS, EW)
# (LTMS ⟂ LTFS, DI, EW, CL, ND, HAC | IC, IS)
# (LTMS ⟂ LTFS, DI, EW, IC, CL, HAC | IS, ND)
# (LTMS ⟂ LTFS, DI, EW, IC, CL, ND | IS, HAC)
# (LTMS ⟂ TF, IS, EW, IC, ND | CL, HTC)
# (LTMS ⟂ IS, DI, EW, IC, ND, HAC | LTFS, CL)
# (LTMS ⟂ LTFS, IS, EW, IC, ND, HAC | CL, DI)
# (LTMS ⟂ LTFS, IS, DI, IC, ND, HAC | CL, EW)
# (LTMS ⟂ LTFS, IS, DI, EW, ND, HAC | IC, CL)
# (LTMS ⟂ LTFS, IS, DI, EW, IC, HAC | CL, ND)
# (LTMS ⟂ LTFS, IS, DI, EW, IC, ND | CL, HAC)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | LTFS, HTC)
# (LTMS ⟂ IS, EW, IC, CL, ND | TF, HTC)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | HTC, DI)
# (LTMS ⟂ TF, IS, IC, CL, ND | HTC, EW)
# (LTMS ⟂ TF, IS, EW, CL, ND | IC, HTC)
# (LTMS ⟂ TF, IS, EW, IC, CL | HTC, ND)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | HTC, HAC)
# (LTMS ⟂ IS, EW, IC, CL, ND, HAC | LTFS, DI)
# (LTMS ⟂ IS, DI, IC, CL, ND, HAC | LTFS, EW)
# (LTMS ⟂ IS, DI, EW, CL, ND, HAC | LTFS, IC)
# (LTMS ⟂ IS, DI, EW, IC, CL, HAC | LTFS, ND)
# (LTMS ⟂ IS, DI, EW, IC, CL, ND | LTFS, HAC)
# (LTMS ⟂ CL, EW | TF, ND)
# (LTMS ⟂ LTFS, IS, IC, CL, ND, HAC | DI, EW)
# (LTMS ⟂ LTFS, IS, EW, CL, ND, HAC | IC, DI)
# (LTMS ⟂ LTFS, IS, EW, IC, CL, HAC | ND, DI)
# (LTMS ⟂ LTFS, IS, EW, IC, CL, ND | DI, HAC)
# (LTMS ⟂ LTFS, IS, DI, CL, ND, HAC | IC, EW)
# (LTMS ⟂ LTFS, IS, DI, IC, CL, HAC | ND, EW)
# (LTMS ⟂ LTFS, IS, DI, IC, CL, ND | HAC, EW)
# (LTMS ⟂ LTFS, IS, DI, EW, CL, HAC | IC, ND)
# (LTMS ⟂ LTFS, IS, DI, EW, CL, ND | IC, HAC)
# (LTMS ⟂ LTFS, IS, DI, EW, IC, CL | ND, HAC)
# (LTMS ⟂ TF, IC, ND, EW | HTC, CL, IS)
# (LTMS ⟂ DI, EW, IC, ND, HAC | LTFS, CL, IS)
# (LTMS ⟂ LTFS, EW, IC, ND, HAC | CL, IS, DI)
# (LTMS ⟂ LTFS, DI, IC, ND, HAC | CL, IS, EW)
# (LTMS ⟂ LTFS, DI, EW, ND, HAC | IC, CL, IS)
# (LTMS ⟂ LTFS, DI, EW, IC, HAC | CL, IS, ND)
# (LTMS ⟂ LTFS, DI, EW, IC, ND | CL, IS, HAC)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS, LTFS)
# (LTMS ⟂ IC, CL, ND, EW | HTC, TF, IS)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS, DI)
# (LTMS ⟂ TF, IC, CL, ND | HTC, IS, EW)
# (LTMS ⟂ TF, CL, ND, EW | HTC, IC, IS)
# (LTMS ⟂ TF, IC, CL, EW | HTC, IS, ND)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS, HAC)
# (LTMS ⟂ EW, IC, CL, ND, HAC | LTFS, IS, DI)
# (LTMS ⟂ DI, IC, CL, ND, HAC | LTFS, IS, EW)
# (LTMS ⟂ DI, EW, CL, ND, HAC | LTFS, IC, IS)
# (LTMS ⟂ DI, EW, IC, CL, HAC | LTFS, IS, ND)
# (LTMS ⟂ DI, EW, IC, CL, ND | LTFS, IS, HAC)
# (LTMS ⟂ CL, EW | TF, IS, ND)
# (LTMS ⟂ LTFS, IC, CL, ND, HAC | IS, DI, EW)
# (LTMS ⟂ LTFS, EW, CL, ND, HAC | IC, IS, DI)
# (LTMS ⟂ LTFS, EW, IC, CL, HAC | IS, DI, ND)
# (LTMS ⟂ LTFS, EW, IC, CL, ND | IS, DI, HAC)
# (LTMS ⟂ LTFS, DI, CL, ND, HAC | IC, IS, EW)
# (LTMS ⟂ LTFS, DI, IC, CL, HAC | IS, ND, EW)
# (LTMS ⟂ LTFS, DI, IC, CL, ND | IS, HAC, EW)
# (LTMS ⟂ LTFS, DI, EW, CL, HAC | IC, IS, ND)
# (LTMS ⟂ LTFS, DI, EW, CL, ND | IC, IS, HAC)
# (LTMS ⟂ LTFS, DI, EW, IC, CL | IS, HAC, ND)
# (LTMS ⟂ TF, IS, EW, IC, ND | LTFS, CL, HTC)
# (LTMS ⟂ IC, IS, ND, EW | TF, CL, HTC)
# (LTMS ⟂ TF, IS, EW, IC, ND | CL, HTC, DI)
# (LTMS ⟂ TF, IC, IS, ND | CL, HTC, EW)
# (LTMS ⟂ TF, IS, ND, EW | IC, CL, HTC)
# (LTMS ⟂ TF, IC, IS, EW | CL, HTC, ND)
# (LTMS ⟂ TF, IS, EW, IC, ND | CL, HTC, HAC)
# (LTMS ⟂ IS, EW, IC, ND, HAC | LTFS, CL, DI)
# (LTMS ⟂ IS, DI, IC, ND, HAC | LTFS, CL, EW)
# (LTMS ⟂ IS, DI, EW, ND, HAC | LTFS, IC, CL)
# (LTMS ⟂ IS, DI, EW, IC, HAC | LTFS, CL, ND)
# (LTMS ⟂ IS, DI, EW, IC, ND | LTFS, CL, HAC)
# (LTMS ⟂ EW | TF, CL, ND)
# (LTMS ⟂ LTFS, IS, IC, ND, HAC | CL, DI, EW)
# (LTMS ⟂ LTFS, IS, EW, ND, HAC | IC, CL, DI)
# (LTMS ⟂ LTFS, IS, EW, IC, HAC | CL, ND, DI)
# (LTMS ⟂ LTFS, IS, EW, IC, ND | CL, DI, HAC)
# (LTMS ⟂ LTFS, IS, DI, ND, HAC | IC, CL, EW)
# (LTMS ⟂ LTFS, IS, DI, IC, HAC | CL, ND, EW)
# (LTMS ⟂ LTFS, IS, DI, IC, ND | CL, HAC, EW)
# (LTMS ⟂ LTFS, IS, DI, EW, HAC | IC, CL, ND)
# (LTMS ⟂ LTFS, IS, DI, EW, ND | IC, CL, HAC)
# (LTMS ⟂ LTFS, IS, DI, EW, IC | CL, ND, HAC)
# (LTMS ⟂ IS, EW, IC, CL, ND | LTFS, TF, HTC)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | LTFS, HTC, DI)
# (LTMS ⟂ TF, IS, IC, CL, ND | LTFS, HTC, EW)
# (LTMS ⟂ TF, IS, EW, CL, ND | LTFS, IC, HTC)
# (LTMS ⟂ TF, IS, EW, IC, CL | LTFS, HTC, ND)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | LTFS, HTC, HAC)
# (LTMS ⟂ IS, EW, IC, CL, ND | TF, HTC, DI)
# (LTMS ⟂ IC, CL, IS, ND | TF, HTC, EW)
# (LTMS ⟂ CL, IS, ND, EW | TF, IC, HTC)
# (LTMS ⟂ IC, CL, IS, EW | TF, HTC, ND)
# (LTMS ⟂ IS, EW, IC, CL, ND | TF, HTC, HAC)
# (LTMS ⟂ TF, IS, IC, CL, ND | HTC, DI, EW)
# (LTMS ⟂ TF, IS, EW, CL, ND | IC, HTC, DI)
# (LTMS ⟂ TF, IS, EW, IC, CL | HTC, DI, ND)
# (LTMS ⟂ TF, IS, EW, IC, CL, ND | HTC, DI, HAC)
# (LTMS ⟂ TF, CL, IS, ND | IC, HTC, EW)
# (LTMS ⟂ TF, IC, CL, IS | HTC, ND, EW)
# (LTMS ⟂ TF, IS, IC, CL, ND | HTC, HAC, EW)
# (LTMS ⟂ TF, CL, IS, EW | IC, HTC, ND)
# (LTMS ⟂ TF, IS, EW, CL, ND | IC, HTC, HAC)
# (LTMS ⟂ TF, IS, EW, IC, CL | HTC, HAC, ND)
# (LTMS ⟂ CL, EW | LTFS, TF, ND)
# (LTMS ⟂ IS, IC, CL, ND, HAC | LTFS, DI, EW)
# (LTMS ⟂ IS, EW, CL, ND, HAC | LTFS, IC, DI)
# (LTMS ⟂ IS, EW, IC, CL, HAC | LTFS, ND, DI)
# (LTMS ⟂ IS, EW, IC, CL, ND | LTFS, DI, HAC)
# (LTMS ⟂ IS, DI, CL, ND, HAC | LTFS, IC, EW)
# (LTMS ⟂ IS, DI, IC, CL, HAC | LTFS, ND, EW)
# (LTMS ⟂ IS, DI, IC, CL, ND | LTFS, HAC, EW)
# (LTMS ⟂ IS, DI, EW, CL, HAC | LTFS, IC, ND)
# (LTMS ⟂ IS, DI, EW, CL, ND | LTFS, IC, HAC)
# (LTMS ⟂ IS, DI, EW, IC, CL | LTFS, ND, HAC)
# (LTMS ⟂ CL, EW | TF, ND, DI)
# (LTMS ⟂ CL | TF, ND, EW)
# (LTMS ⟂ CL, EW | TF, IC, ND)
# (LTMS ⟂ CL, EW | TF, ND, HAC)
# (LTMS ⟂ LTFS, IS, CL, ND, HAC | IC, DI, EW)
# (LTMS ⟂ LTFS, IS, IC, CL, HAC | ND, DI, EW)
# (LTMS ⟂ LTFS, IS, IC, CL, ND | DI, HAC, EW)
# (LTMS ⟂ LTFS, IS, EW, CL, HAC | IC, ND, DI)
# (LTMS ⟂ LTFS, IS, EW, CL, ND | IC, DI, HAC)
# (LTMS ⟂ LTFS, IS, EW, IC, CL | ND, DI, HAC)
# (LTMS ⟂ LTFS, IS, DI, CL, HAC | IC, ND, EW)
# (LTMS ⟂ LTFS, IS, DI, CL, ND | IC, HAC, EW)
# (LTMS ⟂ LTFS, IS, DI, IC, CL | ND, HAC, EW)
# (LTMS ⟂ LTFS, IS, DI, EW, CL | IC, ND, HAC)
# (LTMS ⟂ TF, IC, ND, EW | HTC, CL, IS, LTFS)
# (LTMS ⟂ IC, ND, EW | HTC, TF, CL, IS)
# (LTMS ⟂ TF, IC, ND, EW | HTC, CL, IS, DI)
# (LTMS ⟂ TF, IC, ND | HTC, CL, IS, EW)
# (LTMS ⟂ TF, ND, EW | HTC, IC, CL, IS)
# (LTMS ⟂ TF, IC, EW | HTC, CL, IS, ND)
# (LTMS ⟂ TF, IC, ND, EW | HTC, CL, IS, HAC)
# (LTMS ⟂ IC, ND, HAC, EW | LTFS, CL, IS, DI)
# (LTMS ⟂ IC, ND, DI, HAC | LTFS, CL, IS, EW)
# (LTMS ⟂ ND, DI, HAC, EW | LTFS, IC, CL, IS)
# (LTMS ⟂ IC, DI, HAC, EW | LTFS, CL, IS, ND)
# (LTMS ⟂ IC, ND, DI, EW | LTFS, CL, IS, HAC)
# (LTMS ⟂ EW | TF, CL, IS, ND)
# (LTMS ⟂ LTFS, IC, ND, HAC | CL, IS, DI, EW)
# (LTMS ⟂ LTFS, ND, HAC, EW | IC, CL, IS, DI)
# (LTMS ⟂ LTFS, IC, HAC, EW | CL, IS, DI, ND)
# (LTMS ⟂ LTFS, IC, ND, EW | CL, IS, DI, HAC)
# (LTMS ⟂ LTFS, ND, DI, HAC | IC, CL, IS, EW)
# (LTMS ⟂ LTFS, IC, DI, HAC | CL, IS, ND, EW)
# (LTMS ⟂ LTFS, IC, ND, DI | CL, IS, HAC, EW)
# (LTMS ⟂ LTFS, DI, HAC, EW | IC, CL, IS, ND)
# (LTMS ⟂ LTFS, ND, DI, EW | IC, CL, IS, HAC)
# (LTMS ⟂ LTFS, IC, DI, EW | CL, IS, HAC, ND)
# (LTMS ⟂ IC, CL, ND, EW | HTC, TF, IS, LTFS)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS, LTFS, DI)
# (LTMS ⟂ TF, IC, CL, ND | HTC, IS, LTFS, EW)
# (LTMS ⟂ TF, CL, ND, EW | HTC, IC, IS, LTFS)
# (LTMS ⟂ TF, IC, CL, EW | HTC, IS, LTFS, ND)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS, LTFS, HAC)
# (LTMS ⟂ IC, CL, ND, EW | HTC, TF, IS, DI)
# (LTMS ⟂ IC, CL, ND | HTC, TF, IS, EW)
# (LTMS ⟂ CL, ND, EW | HTC, IC, TF, IS)
# (LTMS ⟂ IC, CL, EW | HTC, TF, IS, ND)
# (LTMS ⟂ IC, CL, ND, EW | HTC, TF, IS, HAC)
# (LTMS ⟂ TF, IC, CL, ND | HTC, IS, DI, EW)
# (LTMS ⟂ TF, CL, ND, EW | HTC, IC, IS, DI)
# (LTMS ⟂ TF, IC, CL, EW | HTC, IS, DI, ND)
# (LTMS ⟂ TF, EW, IC, CL, ND | HTC, IS, DI, HAC)
# (LTMS ⟂ TF, CL, ND | HTC, IC, IS, EW)
# (LTMS ⟂ TF, IC, CL | HTC, IS, ND, EW)
# (LTMS ⟂ TF, IC, CL, ND | HTC, IS, HAC, EW)
# ...
# (HAC ⟂ EW | CL, LTFS, TF, IC, ND)
# (HAC ⟂ LTMS, IS, ND | CL, LTFS, DI, EW, IC)
# (HAC ⟂ LTMS, IS, IC | CL, LTFS, DI, EW, ND)
# (HAC ⟂ LTMS, IS, EW | CL, LTFS, DI, IC, ND)
# (HAC ⟂ LTMS, IS, DI | CL, LTFS, EW, IC, ND)
# (HAC ⟂ EW | CL, TF, DI, IC, ND)
# (HAC ⟂ LTFS, LTMS, IS | CL, DI, EW, IC, ND)
# (HAC ⟂ IC, CL, IS, ND | HTC, LTFS, TF, DI, EW)
# (HAC ⟂ CL, IS, ND, EW | HTC, LTFS, TF, DI, IC)
# (HAC ⟂ IC, CL, IS, EW | HTC, LTFS, TF, DI, ND)
# (HAC ⟂ CL, IS, ND | HTC, LTFS, TF, EW, IC)
# (HAC ⟂ IC, CL, IS | HTC, LTFS, TF, EW, ND)
# (HAC ⟂ CL, IS, EW | HTC, LTFS, TF, IC, ND)
# (HAC ⟂ TF, CL, IS, ND | HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC, CL, IS | HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, CL, IS, EW | HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF, CL, IS | HTC, LTFS, EW, IC, ND)
# (HAC ⟂ CL, IS, ND | HTC, TF, DI, EW, IC)
# (HAC ⟂ IC, CL, IS | HTC, TF, DI, EW, ND)
# (HAC ⟂ CL, IS, EW | HTC, TF, DI, IC, ND)
# (HAC ⟂ CL, IS | HTC, TF, EW, IC, ND)
# (HAC ⟂ TF, CL, IS | HTC, DI, EW, IC, ND)
# (HAC ⟂ CL | LTFS, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL | LTFS, TF, EW, IC, ND)
# (HAC ⟂ LTMS, CL, IS | LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | TF, DI, EW, IC, ND)
# (HAC ⟂ IC, ND, EW | IS, LTMS, CL, HTC, LTFS, TF)
# (HAC ⟂ TF, IC, ND, EW | IS, LTMS, CL, HTC, LTFS, DI)
# (HAC ⟂ TF, IC, ND | IS, LTMS, CL, HTC, LTFS, EW)
# (HAC ⟂ TF, ND, EW | IS, LTMS, CL, HTC, LTFS, IC)
# (HAC ⟂ TF, IC, EW | IS, LTMS, CL, HTC, LTFS, ND)
# (HAC ⟂ IC, ND, EW | IS, LTMS, CL, HTC, TF, DI)
# (HAC ⟂ IC, ND | IS, LTMS, CL, HTC, TF, EW)
# (HAC ⟂ ND, EW | IS, LTMS, CL, HTC, TF, IC)
# (HAC ⟂ IC, EW | IS, LTMS, CL, HTC, TF, ND)
# (HAC ⟂ TF, IC, ND | IS, LTMS, CL, HTC, DI, EW)
# (HAC ⟂ TF, ND, EW | IS, LTMS, CL, HTC, DI, IC)
# (HAC ⟂ TF, IC, EW | IS, LTMS, CL, HTC, DI, ND)
# (HAC ⟂ TF, ND | IS, LTMS, CL, HTC, EW, IC)
# (HAC ⟂ TF, IC | IS, LTMS, CL, HTC, EW, ND)
# (HAC ⟂ TF, EW | IS, LTMS, CL, HTC, IC, ND)
# (HAC ⟂ EW | IS, LTMS, CL, LTFS, TF, ND)
# (HAC ⟂ IC, ND | IS, LTMS, CL, LTFS, DI, EW)
# (HAC ⟂ ND, EW | IS, LTMS, CL, LTFS, DI, IC)
# (HAC ⟂ IC, EW | IS, LTMS, CL, LTFS, DI, ND)
# (HAC ⟂ ND, DI | IS, LTMS, CL, LTFS, EW, IC)
# (HAC ⟂ IC, DI | IS, LTMS, CL, LTFS, EW, ND)
# (HAC ⟂ DI, EW | IS, LTMS, CL, LTFS, IC, ND)
# (HAC ⟂ EW | IS, LTMS, CL, TF, DI, ND)
# (HAC ⟂ EW | IS, LTMS, CL, TF, IC, ND)
# (HAC ⟂ LTFS, ND | IS, LTMS, CL, DI, EW, IC)
# (HAC ⟂ LTFS, IC | IS, LTMS, CL, DI, EW, ND)
# (HAC ⟂ LTFS, EW | IS, LTMS, CL, DI, IC, ND)
# (HAC ⟂ LTFS, DI | IS, LTMS, CL, EW, IC, ND)
# (HAC ⟂ IC, CL, ND, EW | IS, LTMS, HTC, TF, LTFS, DI)
# (HAC ⟂ IC, CL, ND | IS, LTMS, HTC, TF, LTFS, EW)
# (HAC ⟂ CL, ND, EW | IS, LTMS, HTC, TF, LTFS, IC)
# (HAC ⟂ IC, CL, EW | IS, LTMS, HTC, TF, LTFS, ND)
# (HAC ⟂ TF, IC, CL, ND | IS, LTMS, HTC, LTFS, DI, EW)
# (HAC ⟂ TF, CL, ND, EW | IS, LTMS, HTC, LTFS, DI, IC)
# (HAC ⟂ TF, IC, CL, EW | IS, LTMS, HTC, LTFS, DI, ND)
# (HAC ⟂ TF, CL, ND | IS, LTMS, HTC, LTFS, EW, IC)
# (HAC ⟂ TF, IC, CL | IS, LTMS, HTC, LTFS, EW, ND)
# (HAC ⟂ TF, CL, EW | IS, LTMS, HTC, LTFS, IC, ND)
# (HAC ⟂ IC, CL, ND | IS, LTMS, HTC, TF, DI, EW)
# (HAC ⟂ CL, ND, EW | IS, LTMS, HTC, TF, DI, IC)
# (HAC ⟂ IC, CL, EW | IS, LTMS, HTC, TF, DI, ND)
# (HAC ⟂ CL, ND | IS, LTMS, HTC, TF, EW, IC)
# (HAC ⟂ IC, CL | IS, LTMS, HTC, TF, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, HTC, TF, IC, ND)
# (HAC ⟂ TF, CL, ND | IS, LTMS, HTC, DI, EW, IC)
# (HAC ⟂ TF, IC, CL | IS, LTMS, HTC, DI, EW, ND)
# (HAC ⟂ TF, CL, EW | IS, LTMS, HTC, DI, IC, ND)
# (HAC ⟂ TF, CL | IS, LTMS, HTC, EW, IC, ND)
# (HAC ⟂ CL, EW | IS, LTMS, LTFS, TF, DI, ND)
# (HAC ⟂ CL | IS, LTMS, LTFS, TF, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, LTFS, TF, IC, ND)
# (HAC ⟂ CL, ND | IS, LTMS, LTFS, DI, EW, IC)
# (HAC ⟂ IC, CL | IS, LTMS, LTFS, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, LTFS, DI, IC, ND)
# (HAC ⟂ CL, DI | IS, LTMS, LTFS, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, TF, DI, IC, ND)
# (HAC ⟂ CL | IS, LTMS, TF, EW, IC, ND)
# (HAC ⟂ LTFS, CL | IS, LTMS, DI, EW, IC, ND)
# (HAC ⟂ IC, ND, EW | IS, CL, HTC, TF, LTFS, DI)
# (HAC ⟂ IC, ND | IS, CL, HTC, TF, LTFS, EW)
# (HAC ⟂ ND, EW | IS, CL, HTC, TF, LTFS, IC)
# (HAC ⟂ IC, EW | IS, CL, HTC, TF, LTFS, ND)
# (HAC ⟂ TF, IC, ND | IS, CL, HTC, LTFS, DI, EW)
# (HAC ⟂ TF, ND, EW | IS, CL, HTC, LTFS, DI, IC)
# (HAC ⟂ TF, IC, EW | IS, CL, HTC, LTFS, DI, ND)
# (HAC ⟂ TF, ND | IS, CL, HTC, LTFS, EW, IC)
# (HAC ⟂ TF, IC | IS, CL, HTC, LTFS, EW, ND)
# (HAC ⟂ TF, EW | IS, CL, HTC, LTFS, IC, ND)
# (HAC ⟂ IC, ND | IS, CL, HTC, TF, DI, EW)
# (HAC ⟂ ND, EW | IS, CL, HTC, TF, DI, IC)
# (HAC ⟂ IC, EW | IS, CL, HTC, TF, DI, ND)
# (HAC ⟂ ND | IS, CL, HTC, TF, EW, IC)
# (HAC ⟂ IC | IS, CL, HTC, TF, EW, ND)
# (HAC ⟂ EW | IS, CL, HTC, TF, IC, ND)
# (HAC ⟂ TF, ND | IS, CL, HTC, DI, EW, IC)
# (HAC ⟂ TF, IC | IS, CL, HTC, DI, EW, ND)
# (HAC ⟂ TF, EW | IS, CL, HTC, DI, IC, ND)
# (HAC ⟂ TF | IS, CL, HTC, EW, IC, ND)
# (HAC ⟂ EW | IS, CL, LTFS, TF, DI, ND)
# (HAC ⟂ EW | IS, CL, LTFS, TF, IC, ND)
# (HAC ⟂ LTMS, ND | IS, CL, LTFS, DI, EW, IC)
# (HAC ⟂ LTMS, IC | IS, CL, LTFS, DI, EW, ND)
# (HAC ⟂ LTMS, EW | IS, CL, LTFS, DI, IC, ND)
# (HAC ⟂ LTMS, DI | IS, CL, LTFS, EW, IC, ND)
# (HAC ⟂ EW | IS, CL, TF, DI, IC, ND)
# (HAC ⟂ LTFS, LTMS | IS, CL, DI, EW, IC, ND)
# (HAC ⟂ IC, CL, ND | IS, HTC, TF, LTFS, DI, EW)
# (HAC ⟂ CL, ND, EW | IS, HTC, TF, LTFS, DI, IC)
# (HAC ⟂ IC, CL, EW | IS, HTC, TF, LTFS, DI, ND)
# (HAC ⟂ CL, ND | IS, HTC, TF, LTFS, EW, IC)
# (HAC ⟂ IC, CL | IS, HTC, TF, LTFS, EW, ND)
# (HAC ⟂ CL, EW | IS, HTC, TF, LTFS, IC, ND)
# (HAC ⟂ TF, CL, ND | IS, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC, CL | IS, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, CL, EW | IS, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF, CL | IS, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ CL, ND | IS, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC, CL | IS, HTC, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, HTC, TF, DI, IC, ND)
# (HAC ⟂ CL | IS, HTC, TF, EW, IC, ND)
# (HAC ⟂ TF, CL | IS, HTC, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTFS, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL | IS, LTFS, TF, EW, IC, ND)
# (HAC ⟂ LTMS, CL | IS, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, TF, DI, EW, IC, ND)
# (HAC ⟂ IC, IS, EW, ND | LTMS, CL, HTC, LTFS, TF, DI)
# (HAC ⟂ IC, IS, ND | LTMS, CL, HTC, LTFS, TF, EW)
# (HAC ⟂ IS, EW, ND | LTMS, CL, HTC, LTFS, TF, IC)
# (HAC ⟂ IC, IS, EW | LTMS, CL, HTC, LTFS, TF, ND)
# (HAC ⟂ TF, IC, IS, ND | LTMS, CL, HTC, LTFS, DI, EW)
# (HAC ⟂ TF, IS, EW, ND | LTMS, CL, HTC, LTFS, DI, IC)
# (HAC ⟂ TF, IC, IS, EW | LTMS, CL, HTC, LTFS, DI, ND)
# (HAC ⟂ TF, IS, ND | LTMS, CL, HTC, LTFS, EW, IC)
# (HAC ⟂ TF, IC, IS | LTMS, CL, HTC, LTFS, EW, ND)
# (HAC ⟂ TF, IS, EW | LTMS, CL, HTC, LTFS, IC, ND)
# (HAC ⟂ IC, IS, ND | LTMS, CL, HTC, TF, DI, EW)
# (HAC ⟂ IS, EW, ND | LTMS, CL, HTC, TF, DI, IC)
# (HAC ⟂ IC, IS, EW | LTMS, CL, HTC, TF, DI, ND)
# (HAC ⟂ IS, ND | LTMS, CL, HTC, TF, EW, IC)
# (HAC ⟂ IC, IS | LTMS, CL, HTC, TF, EW, ND)
# (HAC ⟂ IS, EW | LTMS, CL, HTC, TF, IC, ND)
# (HAC ⟂ TF, IS, ND | LTMS, CL, HTC, DI, EW, IC)
# (HAC ⟂ TF, IC, IS | LTMS, CL, HTC, DI, EW, ND)
# (HAC ⟂ TF, IS, EW | LTMS, CL, HTC, DI, IC, ND)
# (HAC ⟂ TF, IS | LTMS, CL, HTC, EW, IC, ND)
# (HAC ⟂ EW | LTMS, CL, LTFS, TF, DI, ND)
# (HAC ⟂ EW | LTMS, CL, LTFS, TF, IC, ND)
# (HAC ⟂ IS, ND | LTMS, CL, LTFS, DI, EW, IC)
# (HAC ⟂ IC, IS | LTMS, CL, LTFS, DI, EW, ND)
# (HAC ⟂ IS, EW | LTMS, CL, LTFS, DI, IC, ND)
# (HAC ⟂ IS, DI | LTMS, CL, LTFS, EW, IC, ND)
# (HAC ⟂ EW | LTMS, CL, TF, DI, IC, ND)
# (HAC ⟂ LTFS, IS | LTMS, CL, DI, EW, IC, ND)
# (HAC ⟂ IC, CL, IS, ND | LTMS, HTC, LTFS, TF, DI, EW)
# (HAC ⟂ CL, IS, EW, ND | LTMS, HTC, LTFS, TF, DI, IC)
# (HAC ⟂ IC, CL, IS, EW | LTMS, HTC, LTFS, TF, DI, ND)
# (HAC ⟂ CL, IS, ND | LTMS, HTC, LTFS, TF, EW, IC)
# (HAC ⟂ IC, CL, IS | LTMS, HTC, LTFS, TF, EW, ND)
# (HAC ⟂ CL, IS, EW | LTMS, HTC, LTFS, TF, IC, ND)
# (HAC ⟂ TF, CL, IS, ND | LTMS, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC, CL, IS | LTMS, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, CL, IS, EW | LTMS, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF, CL, IS | LTMS, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ CL, IS, ND | LTMS, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC, CL, IS | LTMS, HTC, TF, DI, EW, ND)
# (HAC ⟂ CL, IS, EW | LTMS, HTC, TF, DI, IC, ND)
# (HAC ⟂ CL, IS | LTMS, HTC, TF, EW, IC, ND)
# (HAC ⟂ TF, CL, IS | LTMS, HTC, DI, EW, IC, ND)
# (HAC ⟂ CL | LTMS, LTFS, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | LTMS, LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL | LTMS, LTFS, TF, EW, IC, ND)
# (HAC ⟂ CL, IS | LTMS, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | LTMS, TF, DI, EW, IC, ND)
# (HAC ⟂ IC, IS, ND | CL, HTC, LTFS, TF, DI, EW)
# (HAC ⟂ IS, EW, ND | CL, HTC, LTFS, TF, DI, IC)
# (HAC ⟂ IC, IS, EW | CL, HTC, LTFS, TF, DI, ND)
# (HAC ⟂ IS, ND | CL, HTC, LTFS, TF, EW, IC)
# (HAC ⟂ IC, IS | CL, HTC, LTFS, TF, EW, ND)
# (HAC ⟂ IS, EW | CL, HTC, LTFS, TF, IC, ND)
# (HAC ⟂ TF, IS, ND | CL, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC, IS | CL, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, IS, EW | CL, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF, IS | CL, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ IS, ND | CL, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC, IS | CL, HTC, TF, DI, EW, ND)
# (HAC ⟂ IS, EW | CL, HTC, TF, DI, IC, ND)
# (HAC ⟂ IS | CL, HTC, TF, EW, IC, ND)
# (HAC ⟂ TF, IS | CL, HTC, DI, EW, IC, ND)
# (HAC ⟂ EW | CL, LTFS, TF, DI, IC, ND)
# (HAC ⟂ LTMS, IS | CL, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL, IS, ND | HTC, LTFS, TF, DI, EW, IC)
# (HAC ⟂ IC, CL, IS | HTC, LTFS, TF, DI, EW, ND)
# (HAC ⟂ CL, IS, EW | HTC, LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL, IS | HTC, LTFS, TF, EW, IC, ND)
# (HAC ⟂ TF, CL, IS | HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL, IS | HTC, TF, DI, EW, IC, ND)
# (HAC ⟂ CL | LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ IC, ND, EW | IS, LTMS, CL, HTC, LTFS, TF, DI)
# (HAC ⟂ IC, ND | IS, LTMS, CL, HTC, LTFS, TF, EW)
# (HAC ⟂ ND, EW | IS, LTMS, CL, HTC, LTFS, TF, IC)
# (HAC ⟂ IC, EW | IS, LTMS, CL, HTC, LTFS, TF, ND)
# (HAC ⟂ TF, IC, ND | IS, LTMS, CL, HTC, LTFS, DI, EW)
# (HAC ⟂ TF, ND, EW | IS, LTMS, CL, HTC, LTFS, DI, IC)
# (HAC ⟂ TF, IC, EW | IS, LTMS, CL, HTC, LTFS, DI, ND)
# (HAC ⟂ TF, ND | IS, LTMS, CL, HTC, LTFS, EW, IC)
# (HAC ⟂ TF, IC | IS, LTMS, CL, HTC, LTFS, EW, ND)
# (HAC ⟂ TF, EW | IS, LTMS, CL, HTC, LTFS, IC, ND)
# (HAC ⟂ IC, ND | IS, LTMS, CL, HTC, TF, DI, EW)
# (HAC ⟂ ND, EW | IS, LTMS, CL, HTC, TF, DI, IC)
# (HAC ⟂ IC, EW | IS, LTMS, CL, HTC, TF, DI, ND)
# (HAC ⟂ ND | IS, LTMS, CL, HTC, TF, EW, IC)
# (HAC ⟂ IC | IS, LTMS, CL, HTC, TF, EW, ND)
# (HAC ⟂ EW | IS, LTMS, CL, HTC, TF, IC, ND)
# (HAC ⟂ TF, ND | IS, LTMS, CL, HTC, DI, EW, IC)
# (HAC ⟂ TF, IC | IS, LTMS, CL, HTC, DI, EW, ND)
# (HAC ⟂ TF, EW | IS, LTMS, CL, HTC, DI, IC, ND)
# (HAC ⟂ TF | IS, LTMS, CL, HTC, EW, IC, ND)
# (HAC ⟂ EW | IS, LTMS, CL, LTFS, TF, DI, ND)
# (HAC ⟂ EW | IS, LTMS, CL, LTFS, TF, IC, ND)
# (HAC ⟂ ND | IS, LTMS, CL, LTFS, DI, EW, IC)
# (HAC ⟂ IC | IS, LTMS, CL, LTFS, DI, EW, ND)
# (HAC ⟂ EW | IS, LTMS, CL, LTFS, DI, IC, ND)
# (HAC ⟂ DI | IS, LTMS, CL, LTFS, EW, IC, ND)
# (HAC ⟂ EW | IS, LTMS, CL, TF, DI, IC, ND)
# (HAC ⟂ LTFS | IS, LTMS, CL, DI, EW, IC, ND)
# (HAC ⟂ IC, CL, ND | IS, LTMS, HTC, TF, LTFS, DI, EW)
# (HAC ⟂ CL, ND, EW | IS, LTMS, HTC, TF, LTFS, DI, IC)
# (HAC ⟂ IC, CL, EW | IS, LTMS, HTC, TF, LTFS, DI, ND)
# (HAC ⟂ CL, ND | IS, LTMS, HTC, TF, LTFS, EW, IC)
# (HAC ⟂ IC, CL | IS, LTMS, HTC, TF, LTFS, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, HTC, TF, LTFS, IC, ND)
# (HAC ⟂ TF, CL, ND | IS, LTMS, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC, CL | IS, LTMS, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, CL, EW | IS, LTMS, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF, CL | IS, LTMS, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ CL, ND | IS, LTMS, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC, CL | IS, LTMS, HTC, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, HTC, TF, DI, IC, ND)
# (HAC ⟂ CL | IS, LTMS, HTC, TF, EW, IC, ND)
# (HAC ⟂ TF, CL | IS, LTMS, HTC, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, LTFS, TF, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL | IS, LTMS, LTFS, TF, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, TF, DI, EW, IC, ND)
# (HAC ⟂ IC, ND | IS, CL, HTC, TF, LTFS, DI, EW)
# (HAC ⟂ ND, EW | IS, CL, HTC, TF, LTFS, DI, IC)
# (HAC ⟂ IC, EW | IS, CL, HTC, TF, LTFS, DI, ND)
# (HAC ⟂ ND | IS, CL, HTC, TF, LTFS, EW, IC)
# (HAC ⟂ IC | IS, CL, HTC, TF, LTFS, EW, ND)
# (HAC ⟂ EW | IS, CL, HTC, TF, LTFS, IC, ND)
# (HAC ⟂ TF, ND | IS, CL, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC | IS, CL, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, EW | IS, CL, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF | IS, CL, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ ND | IS, CL, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC | IS, CL, HTC, TF, DI, EW, ND)
# (HAC ⟂ EW | IS, CL, HTC, TF, DI, IC, ND)
# (HAC ⟂ TF | IS, CL, HTC, DI, EW, IC, ND)
# (HAC ⟂ EW | IS, CL, LTFS, TF, DI, IC, ND)
# (HAC ⟂ LTMS | IS, CL, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL, ND | IS, HTC, TF, LTFS, DI, EW, IC)
# (HAC ⟂ IC, CL | IS, HTC, TF, LTFS, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, HTC, TF, LTFS, DI, IC, ND)
# (HAC ⟂ CL | IS, HTC, TF, LTFS, EW, IC, ND)
# (HAC ⟂ TF, CL | IS, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, HTC, TF, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ IC, IS, ND | LTMS, CL, HTC, LTFS, TF, DI, EW)
# (HAC ⟂ IS, EW, ND | LTMS, CL, HTC, LTFS, TF, DI, IC)
# (HAC ⟂ IC, IS, EW | LTMS, CL, HTC, LTFS, TF, DI, ND)
# (HAC ⟂ IS, ND | LTMS, CL, HTC, LTFS, TF, EW, IC)
# (HAC ⟂ IC, IS | LTMS, CL, HTC, LTFS, TF, EW, ND)
# (HAC ⟂ IS, EW | LTMS, CL, HTC, LTFS, TF, IC, ND)
# (HAC ⟂ TF, IS, ND | LTMS, CL, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC, IS | LTMS, CL, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, IS, EW | LTMS, CL, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF, IS | LTMS, CL, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ IS, ND | LTMS, CL, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC, IS | LTMS, CL, HTC, TF, DI, EW, ND)
# (HAC ⟂ IS, EW | LTMS, CL, HTC, TF, DI, IC, ND)
# (HAC ⟂ IS | LTMS, CL, HTC, TF, EW, IC, ND)
# (HAC ⟂ TF, IS | LTMS, CL, HTC, DI, EW, IC, ND)
# (HAC ⟂ EW | LTMS, CL, LTFS, TF, DI, IC, ND)
# (HAC ⟂ IS | LTMS, CL, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL, IS, ND | LTMS, HTC, LTFS, TF, DI, EW, IC)
# (HAC ⟂ IC, CL, IS | LTMS, HTC, LTFS, TF, DI, EW, ND)
# (HAC ⟂ CL, IS, EW | LTMS, HTC, LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL, IS | LTMS, HTC, LTFS, TF, EW, IC, ND)
# (HAC ⟂ TF, CL, IS | LTMS, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL, IS | LTMS, HTC, TF, DI, EW, IC, ND)
# (HAC ⟂ CL | LTMS, LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ IS, ND | CL, HTC, LTFS, TF, DI, EW, IC)
# (HAC ⟂ IC, IS | CL, HTC, LTFS, TF, DI, EW, ND)
# (HAC ⟂ IS, EW | CL, HTC, LTFS, TF, DI, IC, ND)
# (HAC ⟂ IS | CL, HTC, LTFS, TF, EW, IC, ND)
# (HAC ⟂ TF, IS | CL, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ IS | CL, HTC, TF, DI, EW, IC, ND)
# (HAC ⟂ CL, IS | HTC, LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ IC, ND | IS, LTMS, CL, HTC, LTFS, TF, DI, EW)
# (HAC ⟂ ND, EW | IS, LTMS, CL, HTC, LTFS, TF, DI, IC)
# (HAC ⟂ IC, EW | IS, LTMS, CL, HTC, LTFS, TF, DI, ND)
# (HAC ⟂ ND | IS, LTMS, CL, HTC, LTFS, TF, EW, IC)
# (HAC ⟂ IC | IS, LTMS, CL, HTC, LTFS, TF, EW, ND)
# (HAC ⟂ EW | IS, LTMS, CL, HTC, LTFS, TF, IC, ND)
# (HAC ⟂ TF, ND | IS, LTMS, CL, HTC, LTFS, DI, EW, IC)
# (HAC ⟂ TF, IC | IS, LTMS, CL, HTC, LTFS, DI, EW, ND)
# (HAC ⟂ TF, EW | IS, LTMS, CL, HTC, LTFS, DI, IC, ND)
# (HAC ⟂ TF | IS, LTMS, CL, HTC, LTFS, EW, IC, ND)
# (HAC ⟂ ND | IS, LTMS, CL, HTC, TF, DI, EW, IC)
# (HAC ⟂ IC | IS, LTMS, CL, HTC, TF, DI, EW, ND)
# (HAC ⟂ EW | IS, LTMS, CL, HTC, TF, DI, IC, ND)
# (HAC ⟂ TF | IS, LTMS, CL, HTC, DI, EW, IC, ND)
# (HAC ⟂ EW | IS, LTMS, CL, LTFS, TF, DI, IC, ND)
# (HAC ⟂ CL, ND | IS, LTMS, HTC, TF, LTFS, DI, EW, IC)
# (HAC ⟂ IC, CL | IS, LTMS, HTC, TF, LTFS, DI, EW, ND)
# (HAC ⟂ CL, EW | IS, LTMS, HTC, TF, LTFS, DI, IC, ND)
# (HAC ⟂ CL | IS, LTMS, HTC, TF, LTFS, EW, IC, ND)
# (HAC ⟂ TF, CL | IS, LTMS, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, HTC, TF, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ ND | IS, CL, HTC, TF, LTFS, DI, EW, IC)
# (HAC ⟂ IC | IS, CL, HTC, TF, LTFS, DI, EW, ND)
# (HAC ⟂ EW | IS, CL, HTC, TF, LTFS, DI, IC, ND)
# (HAC ⟂ TF | IS, CL, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, HTC, TF, LTFS, DI, EW, IC, ND)
# (HAC ⟂ IS, ND | LTMS, CL, HTC, LTFS, TF, DI, EW, IC)
# (HAC ⟂ IC, IS | LTMS, CL, HTC, LTFS, TF, DI, EW, ND)
# (HAC ⟂ IS, EW | LTMS, CL, HTC, LTFS, TF, DI, IC, ND)
# (HAC ⟂ IS | LTMS, CL, HTC, LTFS, TF, EW, IC, ND)
# (HAC ⟂ TF, IS | LTMS, CL, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ IS | LTMS, CL, HTC, TF, DI, EW, IC, ND)
# (HAC ⟂ CL, IS | LTMS, HTC, LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ IS | CL, HTC, LTFS, TF, DI, EW, IC, ND)
# (HAC ⟂ ND | IS, LTMS, CL, HTC, LTFS, TF, DI, EW, IC)
# (HAC ⟂ IC | IS, LTMS, CL, HTC, LTFS, TF, DI, EW, ND)
# (HAC ⟂ EW | IS, LTMS, CL, HTC, LTFS, TF, DI, IC, ND)
# (HAC ⟂ TF | IS, LTMS, CL, HTC, LTFS, DI, EW, IC, ND)
# (HAC ⟂ CL | IS, LTMS, HTC, TF, LTFS, DI, EW, IC, ND)
# (HAC ⟂ IS | LTMS, CL, HTC, LTFS, TF, DI, EW, IC, ND)

# %%
print('There can be made {} valid independence assertions, with respect to the all possible given evidence.'.format(len(Flakiness_model.get_independencies().get_assertions())), "\n")
independencies = Flakiness_model.get_independencies() 
# print(independencies) # Output is not shown for compactness sake

values = list(cpds.values())
# print(values)
variables=['DI', 'LTFS', 'HAC', 'LTMS', 'EW', 'CL', 'IS', 'IC', 'ND', 'HTC', 'TF']

[Flakiness_model.add_cpds(x) for x in values];

for variable in variables:
    print("The local independencies for \'{}\' are:".format(variable), "\n" ,Flakiness_model.local_independencies(variable), "\n")
# Out:
# There can be made 9016 valid independence assertions, with respect to the all possible given evidence.
#
# The local independencies for 'DI' are:
#  (DI ⟂ IS, LTMS, CL, LTFS, EW, IC, ND, HAC)
#
# The local independencies for 'LTFS' are:
#  (LTFS ⟂ IS, LTMS, CL, DI, EW, IC, ND, HAC)
#
# The local independencies for 'HAC' are:
#  (HAC ⟂ IS, LTMS, CL, LTFS, DI, EW, IC, ND)
#
# The local independencies for 'LTMS' are:
#  (LTMS ⟂ IS, CL, LTFS, DI, EW, IC, ND, HAC)
#
# The local independencies for 'EW' are:
#  (EW ⟂ IS, LTMS, CL, HTC, LTFS, DI, IC, HAC)
#
# The local independencies for 'CL' are:
#  (CL ⟂ IS, LTMS, HTC, LTFS, DI, EW, IC, HAC)
#
# The local independencies for 'IS' are:
#  (IS ⟂ LTMS, CL, HTC, LTFS, DI, EW, IC, ND, HAC)
#
# The local independencies for 'IC' are:
#  (IC ⟂ IS, LTMS, CL, HTC, LTFS, DI, EW, ND, HAC)
#
# The local independencies for 'ND' are:
#  (ND ⟂ LTFS, IS, DI, LTMS, HTC, IC, HAC | CL, EW)
#
# The local independencies for 'HTC' are:
#  (HTC ⟂ IS, EW, IC, CL, ND | LTFS, LTMS, DI, HAC)
#
# The local independencies for 'TF' are:
#  (TF ⟂ LTFS, DI, EW, LTMS, CL, HAC | IC, IS, HTC, ND)

# %%
Flakiness_model.active_trail_nodes("ND")
# Out:
# {'ND': {'CL', 'EW', 'ND', 'TF'}}

# %% [markdown]
# ##### Markov Blanket

# %%
leaves = Flakiness_model.get_leaves()
markov_blanket = {}


for node in nodes:
    if not node in leaves:
        markov_blanket[node] = Flakiness_model.get_markov_blanket(node)
        print('The node \'{}\' has Markov blanket: {}.'.format(node, markov_blanket[node]))
        print('\n')
        
        nx.draw_networkx_nodes(DAG, pos, nodelist = [node], node_color = 'red')
        nx.draw_networkx_nodes(DAG, pos, nodelist = markov_blanket[node], node_color = 'yellow')
        nx.draw_networkx_nodes(DAG, pos, 
               nodelist = [n for n in nodes if n not in markov_blanket[node] and n != node], 
               node_color = 'grey')
        nx.draw_networkx_labels(DAG, pos)
        nx.draw_networkx_labels(DAG, pos)
        nx.draw_networkx_edges(DAG, pos, edge_color = 'purple', width = 1.5, arrows = True)
        plt.show()

        print('\n')
        print("❈"*85,"\n")
# Out:
# The node 'DI' has Markov blanket: ['LTMS', 'HTC', 'LTFS', 'HAC'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'HTC' has Markov blanket: ['IS', 'LTMS', 'TF', 'LTFS', 'DI', 'IC', 'ND', 'HAC'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'LTFS' has Markov blanket: ['LTMS', 'HTC', 'DI', 'HAC'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'HAC' has Markov blanket: ['LTMS', 'HTC', 'LTFS', 'DI'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'LTMS' has Markov blanket: ['HTC', 'LTFS', 'DI', 'HAC'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'ND' has Markov blanket: ['IS', 'CL', 'HTC', 'TF', 'EW', 'IC'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'EW' has Markov blanket: ['CL', 'ND'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'CL' has Markov blanket: ['ND', 'EW'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'IS' has Markov blanket: ['HTC', 'TF', 'IC', 'ND'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈
#
# The node 'IC' has Markov blanket: ['IS', 'HTC', 'TF', 'ND'].
# ❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈❈

# %% [markdown]
# ### Queries

# %% [markdown]
# ##### Exact inference with variable elimination

# %%
exact_inference_variable_elimination = VariableElimination(Flakiness_model)

print('P(Test flakiness)')
query1 = exact_inference_variable_elimination.query(['TF'], show_progress = False);
print(query1)
# Out:
# P(Test flakiness)
# +-------+-----------+
# | TF    |   phi(TF) |
# +=======+===========+
# | TF(0) |    0.3542 |
# +-------+-----------+
# | TF(1) |    0.6458 |
# +-------+-----------+

# %%
print('P(test flakiness|ND = True, HTC = True)')
query2 = exact_inference_variable_elimination.query(['TF'], {'ND': True, 'HTC': True} , show_progress = False);
print(query2)
# Out:
# P(test flakiness|ND = True, HTC = True)
# +-------+-----------+
# | TF    |   phi(TF) |
# +=======+===========+
# | TF(0) |    0.1040 |
# +-------+-----------+
# | TF(1) |    0.8960 |
# +-------+-----------+

# %%
print('P(Non determinism)')
query3 = exact_inference_variable_elimination.query(['ND'], show_progress = False);
print(query3)
# Out:
# P(Non determinism)
# +-------+-----------+
# | ND    |   phi(ND) |
# +=======+===========+
# | ND(0) |    0.8712 |
# +-------+-----------+
# | ND(1) |    0.1288 |
# +-------+-----------+

# %%
print('P(Non determinism| TF = True)')
query9 = exact_inference_variable_elimination.query(['ND'],{ 'TF': True}, show_progress = False);
print(query9)
# Out:
# P(Non determinism| TF = True)
# +-------+-----------+
# | ND    |   phi(ND) |
# +=======+===========+
# | ND(0) |    0.8290 |
# +-------+-----------+
# | ND(1) |    0.1710 |
# +-------+-----------+

# %%
print('P(HTC)')
query4 = exact_inference_variable_elimination.query(['HTC'], show_progress = False);
print(query4)
# Out:
# P(HTC)
# +--------+------------+
# | HTC    |   phi(HTC) |
# +========+============+
# | HTC(0) |     0.3110 |
# +--------+------------+
# | HTC(1) |     0.6890 |
# +--------+------------+

# %%
print('P(HTC|TF= True)')
query5 = exact_inference_variable_elimination.query(['HTC'], { 'TF': True} , show_progress = False);
print(query5)
# Out:
# P(HTC|TF= True)
# +--------+------------+
# | HTC    |   phi(HTC) |
# +========+============+
# | HTC(0) |     0.1508 |
# +--------+------------+
# | HTC(1) |     0.8492 |
# +--------+------------+

# %%
print('P(TF|HTC= False, IC=False, ND=False, IS=False)')
query6 = exact_inference_variable_elimination.query(['TF'], { 'HTC': False, 'IC':False, 'ND':False, 'IS':False} , show_progress = False);
print(query6)
# Out:
# P(TF|HTC= False, IC=False, ND=False, IS=False)
# +-------+-----------+
# | TF    |   phi(TF) |
# +=======+===========+
# | TF(0) |    0.9000 |
# +-------+-----------+
# | TF(1) |    0.1000 |
# +-------+-----------+

# %%
print('P(TF|HTC= True, IC=True, ND=False, IS=False)')
query8 = exact_inference_variable_elimination.query(['TF'], { 'HTC': True, 'IC':True, 'ND':False, 'IS':False} , show_progress = False);
print(query8)
# Out:
# P(TF|HTC= True, IC=True, ND=False, IS=False)
# +-------+-----------+
# | TF    |   phi(TF) |
# +=======+===========+
# | TF(0) |    0.1600 |
# +-------+-----------+
# | TF(1) |    0.8400 |
# +-------+-----------+

# %%
print('P(TF|DI= True, IC=False, EW=True, IS=False)')
query7 = exact_inference_variable_elimination.query(['TF'], { 'DI': True, 'IC':False, 'EW':True, 'IS':False} , show_progress = False);
print(query7)
# Out:
# P(TF|DI= True, IC=False, EW=True, IS=False)
# +-------+-----------+
# | TF    |   phi(TF) |
# +=======+===========+
# | TF(0) |    0.5362 |
# +-------+-----------+
# | TF(1) |    0.4638 |
# +-------+-----------+

# %% [markdown]
# ### Approximate inference

# %%
''' Reference query for comparison'''
reference_query = exact_inference_variable_elimination.query(['TF'], {'ND' : True, 'HTC' : True}, show_progress = False).values[1]
print('P(TF = False|ND = True, HTC = True) = {}.'.format(reference_query))
# Out:
# P(TF = False|ND = True, HTC = True) = 0.896.

# %%
inference = BayesianModelSampling(Flakiness_model)

evidences = [State('ND', True), State('HTC', True)]
verbose = False
sample_size = 10

def prob_LW(samples, variable):
    return round(np.sum(np.dot(samples[variable], samples['_weight']))/np.sum(samples['_weight']), 2)

def relative_error(exact_value, approx_value):
    return np.absolute((exact_value - approx_value)/exact_value)

def absolute_error(exact_value, approx_value):
    return np.absolute(exact_value - approx_value)

def run_experiment(sample_size):
    # Sample
    samples_LW = inference.likelihood_weighted_sample(evidence = evidences, 
                                                      size = sample_size, 
                                                      )
    
    samples_RS = inference.rejection_sample(evidence = evidences, 
                                            size = sample_size, 
                                            )
    
    # Statistics
    query_LW = prob_LW(samples_LW, 'TF')
    query_RS = np.mean(samples_RS['TF'], axis = 0)

      
    # Return results
    return np.array([(sample_size, 
                      query_RS, absolute_error(reference_query, query_RS),
                      query_LW, absolute_error(reference_query, query_LW))],
                    dtype = [('sample_size', '<i8'), 
                             ('query_RS', '<f8'),('e_query_RS', '<f8'),
                             ('query_LW', '<f8'),('e_query_LW', '<f8')])

# %%
results = np.array([], dtype = [('sample_size', '<i8'), 
                                ('query_RS', '<f8'), ('e_query_RS', '<f8'),
                                ('query_LW', '<f8'), ('e_query_LW', '<f8')])

starting_size_ = 1 
final_size = 5    
experiments = 10

for size in np.logspace(starting_size_, final_size, num = experiments, dtype = '<i8'):
    results = np.append(results, run_experiment(size))
    
print(results)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/77 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/215 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/599 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/1668 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/4641 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/12915 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/35938 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# [(    10, 0.7       , 1.96000000e-01, 1.  , 0.104)
#  (    27, 0.81481481, 8.11851852e-02, 0.98, 0.084)
#  (    77, 0.8961039 , 1.03896104e-04, 0.71, 0.186)
#  (   215, 0.91162791, 1.56279070e-02, 0.98, 0.084)
#  (   599, 0.88981636, 6.18363940e-03, 0.84, 0.056)
#  (  1668, 0.89748201, 1.48201439e-03, 0.89, 0.006)
#  (  4641, 0.89937513, 3.37513467e-03, 0.88, 0.016)
#  ( 12915, 0.89454123, 1.45876887e-03, 0.9 , 0.004)
#  ( 35938, 0.89601536, 1.53597863e-05, 0.89, 0.006)
#  (100000, 0.89755   , 1.55000000e-03, 0.9 , 0.004)]

# %%
''' Comparison '''
plt.figure(figsize = (15, 10))
# Plot 1

plt.xlabel("Number of samples")
plt.ylabel("Probability")
#plt.title(f'P({'TF'} | {'ND'} = True, {'HTC'} = True)')
LWCplot, = plt.semilogx(results['sample_size'],
                        results['query_LW'],
                        '-bo',
                        label = "Likelihood Weighting")

RSCplot, = plt.semilogx(results['sample_size'],
                        results['query_RS'],
                        '-go',
                        label = "Rejection Sampling")

VECplot, = plt.semilogx(results['sample_size'],
                        reference_query*np.ones(results.size),
                        'r',
                        label = "Reference value")

plt.legend(handles = [LWCplot, RSCplot, VECplot])

plt.show()
# Plot 2
plt.figure(figsize = (15, 10))

plt.xlabel("Number of samples")
plt.ylabel("Absolute error")
#plt.title(f'Absolute error on P({'TF'} | {'ND'} = True, {'HTC'} = True)')
ELWCplot, = plt.semilogx(results['sample_size'],
                         results['e_query_LW'],
                         'bo-',
                         label = "Likelihood Weighting")

ERSCplot, = plt.semilogx(results['sample_size'],
                         results['e_query_RS'],
                         'go-',
                         label = "Rejection Sampling")

plt.legend(handles = [ELWCplot, ERSCplot])

plt.show()
